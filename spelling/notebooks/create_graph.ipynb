# %%
import sys
sys.path.append("..")

from phoneme import Graph, Phoneme

graph = Graph()
graph.add_connections([Phoneme.from_string("S"), Phoneme.from_string("T"), Phoneme.from_string("AH0"), Phoneme.from_string("P")])
graph
# Out:
# Graph(connections=[Connection(left=S, right=T, count=1), Connection(left=T, right=AH, count=1), Connection(left=AH, right=P, count=1)])
