# %% [markdown]
# # Goals

# %%
import pronouncing

word = "hello"
phonemes = pronouncing.phones_for_word(word)
print(phonemes)
# Out:
# ['HH AH0 L OW1', 'HH EH0 L OW1']

# %%
def word_to_phonemes(word):
    """
    Convert a word to its ARPAbet phonemes and analyze its structure.
    """
    phoneme_list = pronouncing.phones_for_word(word)

    if not phoneme_list:
        return f"Word '{word}' not found in CMUdict."

    # Take the first pronunciation (CMUdict sometimes has multiple)
    phonemes = phoneme_list[0]
    
    # Split phonemes into a list
    phoneme_tokens = phonemes.split()
    
    # Count vowels and consonants
    vowels = {"IY", "IH", "EY", "EH", "AE", "AA", "AO", "OW", "UH", "UW", "ER", "AX", "AH", "AY", "AW", "OY"}
    vowel_count = sum(1 for phoneme in phoneme_tokens if phoneme[:2] in vowels)
    consonant_count = len(phoneme_tokens) - vowel_count

    # Count syllables (stress markers 0, 1, 2 indicate syllables)
    syllable_count = sum(1 for phoneme in phoneme_tokens if phoneme[-1].isdigit())

    # Display results
    result = {
        "Word": word,
        "Phonemes": phonemes,
        "Vowel Count": vowel_count,
        "Consonant Count": consonant_count,
        "Syllable Count": syllable_count
    }

    return result

# Example Usage
word = "hello"
result = word_to_phonemes(word)
print(result)
# Out:
# {'Word': 'hello', 'Phonemes': 'HH AH0 L OW1', 'Vowel Count': 2, 'Consonant Count': 2, 'Syllable Count': 2}

# %%
import requests
import wikipediaapi
import json

# Define a User-Agent string
HEADERS = {
    "User-Agent": "MyWikipediaScraper/1.0 (your_email@example.com)"
}

def get_trending_wikipedia_articles(limit=10):
    """
    Fetch trending Wikipedia articles from the Wikipedia API.
    """

    url = "https://en.wikipedia.org/api/rest_v1/feed/featured/2025/02/22"  # Replace with today's date
    response = requests.get(url, headers=HEADERS)
    
    if response.status_code != 200:
        print("Failed to fetch trending articles.")
        return []
    
    data = response.json()
    articles = [article['title'] for article in data.get('mostread', {}).get('articles', [])]
    return articles[:limit]  # Return top N articles

def fetch_wikipedia_text(title):
    """
    Fetch the full text of a Wikipedia article.
    """

    wiki = wikipediaapi.Wikipedia('en', headers=HEADERS)
    page = wiki.page(title)
    
    if not page.exists():
        return None
    
    return page.text

def save_dataset(articles_data, filename="data/wikipedia_dataset.json"):
    """
    Save collected Wikipedia articles as a JSON file.
    """

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(articles_data, f, indent=4)
    
    print(f"Dataset saved as {filename}")

# Main Execution
popular_articles = get_trending_wikipedia_articles(limit=50)  # Get top 5 articles
dataset = {}

for title in popular_articles:
    print(f"Fetching article: {title}...")
    text = fetch_wikipedia_text(title)
    if text:
        dataset[title] = text

# Save to JSON
save_dataset(dataset)
# Out:
# Fetching article: 2025_4_Nations_Face-Off...
# Fetching article: Kash_Patel...
# Fetching article: Severance_(TV_series)...
# Fetching article: Chhaava...
# Fetching article: Null...
# Fetching article: Zero_Day_(American_TV_series)...
# Fetching article: Sambhaji...
# Fetching article: List_of_Toy_Story_characters...
# Fetching article: Elon_Musk...
# Fetching article: Killing_of_Gabby_Petito...
# Fetching article: Belle_Gibson...
# Fetching article: Sidney_Crosby...
# Fetching article: Apple_Network_Server...
# Fetching article: The_Gorge_(film)...
# Fetching article: Deaths_in_2025...
# Fetching article: Brady_Tkachuk...
# Fetching article: Connor_McDavid...
# Fetching article: Captain_America:_Brave_New_World...
# Fetching article: Matthew_Tkachuk...
# Fetching article: Janet_Mills...
# Fetching article: 2024–25_UEFA_Champions_League...
# Fetching article: Hunter_Schafer...
# Fetching article: Rekha_Gupta...
# Fetching article: Keith_Tkachuk...
# Fetching article: Dragon_(2025_film)...
# Fetching article: ChatGPT...
# Fetching article: Kidnapping_of_the_Bibas_family...
# Fetching article: The_White_Lotus_season_3...
# Fetching article: The_Monkey_(film)...
# Fetching article: Shivaji...
# Fetching article: Donald_Trump...
# Fetching article: Reacher_(TV_series)...
# Fetching article: Jordan_Binnington...
# Fetching article: P._K._Subban...
# Fetching article: The_White_Lotus...
# Fetching article: Natalia_Grace...
# Fetching article: The_Traitors_(American_TV_series)_season_3...
# Fetching article: Chris_Kluwe...
# Fetching article: ICC_Champions_Trophy...
# Fetching article: Alan_Ritchson...
# Fetching article: 2024–25_UEFA_Europa_League...
# Fetching article: Aurangzeb...
# Fetching article: Connor_Hellebuyck...
# Dataset saved as data/wikipedia_dataset.json

# %%
def load_datset(filename="data/wikipedia_dataset.json"):
    """
    Load collected Wikipedia articles into a Python dict.
    """

    dataset = {}
    with open(filename, "r", encoding="utf-8") as f:
        raw_file = f.read()
        dataset = json.loads(raw_file)
    
    return dataset

dataset = load_datset()

# %%
def split_words(text):
    valid = "abcdefghijklmnopqrstuvwxyz'"
    valid += valid.upper()
    boundry = "()/,:;.?!*$- "

    current_word = ""
    all_words = []
    for char in text:
        if char in valid:
            current_word += char
        elif char in boundry and current_word != "":
            all_words.append(current_word)
            current_word = ""
        else:
            current_word = ""
    
    return all_words

for title, article in dataset.items():
    print(title)
    words = split_words(article)
    phonemes = [word_to_phonemes(word) for word in words]
    display(phonemes)
    break
# Out:
# 2025_4_Nations_Face-Off
# [{'Word': 'The',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Nations',
#   'Phonemes': 'N EY1 SH AH0 N Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Face',
#   'Phonemes': 'F EY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Off',
#   'Phonemes': 'AO1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'French',
#   'Phonemes': 'F R EH1 N CH',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'Confrontation',
#   'Phonemes': 'K AA2 N F R AH0 N T EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 8,
#   'Syllable Count': 4},
#  {'Word': 'des',
#   'Phonemes': 'D EH1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'nations',
#   'Phonemes': 'N EY1 SH AH0 N Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'an',
#   'Phonemes': 'AE1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'international',
#   'Phonemes': 'IH2 N T ER0 N AE1 SH AH0 N AH0 L',
#   'Vowel Count': 5,
#   'Consonant Count': 6,
#   'Syllable Count': 5},
#  {'Word': 'ice',
#   'Phonemes': 'AY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'hockey',
#   'Phonemes': 'HH AA1 K IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'held',
#   'Phonemes': 'HH EH1 L D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'February',
#   'Phonemes': 'F EH1 B Y AH0 W EH2 R IY0',
#   'Vowel Count': 4,
#   'Consonant Count': 5,
#   'Syllable Count': 4},
#  {'Word': 'The',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'games',
#   'Phonemes': 'G EY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'played',
#   'Phonemes': 'P L EY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Montreal',
#   'Phonemes': 'M AH2 N T R IY0 AO1 L',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'at',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Bell',
#   'Phonemes': 'B EH1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Centre',
#   'Phonemes': 'S EH1 N T ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Boston',
#   'Phonemes': 'B AA1 S T AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'at',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'TD' not found in CMUdict.",
#  {'Word': 'Garden',
#   'Phonemes': 'G AA1 R D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Hosted',
#   'Phonemes': 'HH OW1 S T IH0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'by',
#   'Phonemes': 'B AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'National',
#   'Phonemes': 'N AE1 SH AH0 N AH0 L',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'Hockey',
#   'Phonemes': 'HH AA1 K IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'League',
#   'Phonemes': 'L IY1 G',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'featuring',
#   'Phonemes': 'F IY1 CH ER0 IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'only',
#   'Phonemes': 'OW1 N L IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Nations',
#   'Phonemes': 'N EY1 SH AH0 N Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Face',
#   'Phonemes': 'F EY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Off',
#   'Phonemes': 'AO1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'temporarily',
#   'Phonemes': 'T EH2 M P ER0 EH1 R AH0 L IY0',
#   'Vowel Count': 5,
#   'Consonant Count': 5,
#   'Syllable Count': 5},
#  {'Word': 'replaced',
#   'Phonemes': 'R IY2 P L EY1 S T',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL's' not found in CMUdict.",
#  {'Word': 'annual',
#   'Phonemes': 'AE1 N Y UW0 AH0 L',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'All',
#   'Phonemes': 'AO1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Star',
#   'Phonemes': 'S T AA1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Game',
#   'Phonemes': 'G EY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'In',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'representing',
#   'Phonemes': 'R EH2 P R IH0 Z EH1 N T IH0 NG',
#   'Vowel Count': 4,
#   'Consonant Count': 7,
#   'Syllable Count': 4},
#  {'Word': 'Canada',
#   'Phonemes': 'K AE1 N AH0 D AH0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'Finland',
#   'Phonemes': 'F IH1 N L AE2 N D',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'Sweden',
#   'Phonemes': 'S W IY1 D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'United',
#   'Phonemes': 'Y UW0 N AY1 T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'States',
#   'Phonemes': 'S T EY1 T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'played',
#   'Phonemes': 'P L EY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'each',
#   'Phonemes': 'IY1 CH',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'other',
#   'Phonemes': 'AH1 DH ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 1,
#   'Syllable Count': 2},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'round',
#   'Phonemes': 'R AW1 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'robin',
#   'Phonemes': 'R AA1 B AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'format',
#   'Phonemes': 'F AO1 R M AE2 T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'followed',
#   'Phonemes': 'F AA1 L OW0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'by',
#   'Phonemes': 'B AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'one',
#   'Phonemes': 'W AH1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'game',
#   'Phonemes': 'G EY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'final',
#   'Phonemes': 'F AY1 N AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'two',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'top',
#   'Phonemes': 'T AA1 P',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'placed',
#   'Phonemes': 'P L EY1 S T',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Although',
#   'Phonemes': 'AO2 L DH OW1',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'each',
#   'Phonemes': 'IY1 CH',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': "team's",
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'respective',
#   'Phonemes': 'R IH0 S P EH1 K T IH0 V',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'national',
#   'Phonemes': 'N AE1 SH AH0 N AH0 L',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'ice',
#   'Phonemes': 'AY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'hockey',
#   'Phonemes': 'HH AA1 K IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'governing',
#   'Phonemes': 'G AH1 V ER0 N IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'body',
#   'Phonemes': 'B AA1 D IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'selected',
#   'Phonemes': 'S AH0 L EH1 K T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'rosters',
#   'Phonemes': 'R AA1 S T ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'an',
#   'Phonemes': 'AE1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'only',
#   'Phonemes': 'OW1 N L IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'event',
#   'Phonemes': 'IH0 V EH1 N T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'not',
#   'Phonemes': 'N AA1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'affiliated',
#   'Phonemes': 'AH0 F IH1 L IY0 EY2 T IH0 D',
#   'Vowel Count': 5,
#   'Consonant Count': 4,
#   'Syllable Count': 5},
#  {'Word': 'with',
#   'Phonemes': 'W IH1 DH',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'International',
#   'Phonemes': 'IH2 N T ER0 N AE1 SH AH0 N AH0 L',
#   'Vowel Count': 5,
#   'Consonant Count': 6,
#   'Syllable Count': 5},
#  {'Word': 'Ice',
#   'Phonemes': 'AY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Hockey',
#   'Phonemes': 'HH AA1 K IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'Federation',
#   'Phonemes': 'F EH2 D ER0 EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 4,
#   'Syllable Count': 4},
#  {'Word': 'Canada',
#   'Phonemes': 'K AE1 N AH0 D AH0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'won',
#   'Phonemes': 'W AH1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'after',
#   'Phonemes': 'AE1 F T ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'defeating',
#   'Phonemes': 'D IH0 F IY1 T IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'United',
#   'Phonemes': 'Y UW0 N AY1 T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'States',
#   'Phonemes': 'S T EY1 T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'overtime',
#   'Phonemes': 'OW1 V ER0 T AY2 M',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'of',
#   'Phonemes': 'AH1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'final',
#   'Phonemes': 'F AY1 N AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Reactions',
#   'Phonemes': 'R IY0 AE1 K SH AH0 N Z',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'from',
#   'Phonemes': 'F R AH1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'sports',
#   'Phonemes': 'S P AO1 R T S',
#   'Vowel Count': 1,
#   'Consonant Count': 5,
#   'Syllable Count': 1},
#  {'Word': 'journalists',
#   'Phonemes': 'JH ER1 N AH0 L AH0 S T S',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'positive',
#   'Phonemes': 'P AA1 Z AH0 T IH0 V',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'viewed',
#   'Phonemes': 'V Y UW1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'as',
#   'Phonemes': 'AE1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'welcome',
#   'Phonemes': 'W EH1 L K AH0 M',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'change',
#   'Phonemes': 'CH EY1 N JH',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'from',
#   'Phonemes': 'F R AH1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'All',
#   'Phonemes': 'AO1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Star',
#   'Phonemes': 'S T AA1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Game',
#   'Phonemes': 'G EY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'format',
#   'Phonemes': 'F AO1 R M AE2 T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'The',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Nations',
#   'Phonemes': 'N EY1 SH AH0 N Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Face',
#   'Phonemes': 'F EY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Off',
#   'Phonemes': 'AO1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'announced',
#   'Phonemes': 'AH0 N AW1 N S T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'at',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'press',
#   'Phonemes': 'P R EH1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'conference',
#   'Phonemes': 'K AA1 N F ER0 AH0 N S',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'at',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'All',
#   'Phonemes': 'AO1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Star',
#   'Phonemes': 'S T AA1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Game',
#   'Phonemes': 'G EY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'on',
#   'Phonemes': 'AA1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'February',
#   'Phonemes': 'F EH1 B Y AH0 W EH2 R IY0',
#   'Vowel Count': 4,
#   'Consonant Count': 5,
#   'Syllable Count': 4},
#  {'Word': 'by',
#   'Phonemes': 'B AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'commissioner',
#   'Phonemes': 'K AH0 M IH1 SH AH0 N ER0',
#   'Vowel Count': 4,
#   'Consonant Count': 4,
#   'Syllable Count': 4},
#  {'Word': 'Gary',
#   'Phonemes': 'G EH1 R IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'Bettman',
#   'Phonemes': 'B EH1 T M AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Also',
#   'Phonemes': 'AO1 L S OW0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'present',
#   'Phonemes': 'P R EH1 Z AH0 N T',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'at',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'press',
#   'Phonemes': 'P R EH1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'conference',
#   'Phonemes': 'K AA1 N F ER0 AH0 N S',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': "Players'",
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Association',
#   'Phonemes': 'AH0 S OW2 S IY0 EY1 SH AH0 N',
#   'Vowel Count': 5,
#   'Consonant Count': 4,
#   'Syllable Count': 5},
#  "Word 'NHLPA' not found in CMUdict.",
#  {'Word': 'executive',
#   'Phonemes': 'IH0 G Z EH1 K Y AH0 T IH0 V',
#   'Vowel Count': 4,
#   'Consonant Count': 6,
#   'Syllable Count': 4},
#  {'Word': 'director',
#   'Phonemes': 'D ER0 EH1 K T ER0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'Marty',
#   'Phonemes': 'M AA1 R T IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Walsh',
#   'Phonemes': 'W AO1 L SH',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'four',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Connor',
#   'Phonemes': 'K AA1 N ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'McDavid',
#   'Phonemes': 'M AH0 K D EY1 V AH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'Canada',
#   'Phonemes': 'K AE1 N AH0 D AH0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'Sebastian',
#   'Phonemes': 'S AH0 B AE1 S CH AH0 N',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'Aho',
#   'Phonemes': 'AA1 HH OW0',
#   'Vowel Count': 2,
#   'Consonant Count': 1,
#   'Syllable Count': 2},
#  {'Word': 'Finland',
#   'Phonemes': 'F IH1 N L AE2 N D',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'Elias',
#   'Phonemes': 'AH0 L AY1 AH0 S',
#   'Vowel Count': 3,
#   'Consonant Count': 2,
#   'Syllable Count': 3},
#  {'Word': 'Pettersson',
#   'Phonemes': 'P IY1 T ER0 S AH0 N',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'Sweden',
#   'Phonemes': 'S W IY1 D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Auston',
#   'Phonemes': 'AO1 S T AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Matthews',
#   'Phonemes': 'M AE1 TH Y UW0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'United',
#   'Phonemes': 'Y UW0 N AY1 T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'States',
#   'Phonemes': 'S T EY1 T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'At',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'press',
#   'Phonemes': 'P R EH1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'conference',
#   'Phonemes': 'K AA1 N F ER0 AH0 N S',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'Bettman',
#   'Phonemes': 'B EH1 T M AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'announced',
#   'Phonemes': 'AH0 N AW1 N S T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'plans',
#   'Phonemes': 'P L AE1 N Z',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'participation',
#   'Phonemes': 'P AA0 R T IH2 S AH0 P EY1 SH AH0 N',
#   'Vowel Count': 5,
#   'Consonant Count': 7,
#   'Syllable Count': 5},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'international',
#   'Phonemes': 'IH2 N T ER0 N AE1 SH AH0 N AH0 L',
#   'Vowel Count': 5,
#   'Consonant Count': 6,
#   'Syllable Count': 5},
#  {'Word': 'best',
#   'Phonemes': 'B EH1 S T',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'on',
#   'Phonemes': 'AA1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'best',
#   'Phonemes': 'B EH1 S T',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'tournaments',
#   'Phonemes': 'T ER1 N AH0 M AH0 N T S',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'coming',
#   'Phonemes': 'K AH1 M IH0 NG',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'years',
#   'Phonemes': 'Y IH1 R Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'In',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'participated',
#   'Phonemes': 'P AA0 R T IH1 S AH0 P EY2 T IH0 D',
#   'Vowel Count': 5,
#   'Consonant Count': 7,
#   'Syllable Count': 5},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Nations',
#   'Phonemes': 'N EY1 SH AH0 N Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Face',
#   'Phonemes': 'F EY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Off',
#   'Phonemes': 'AO1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'representing',
#   'Phonemes': 'R EH2 P R IH0 Z EH1 N T IH0 NG',
#   'Vowel Count': 4,
#   'Consonant Count': 7,
#   'Syllable Count': 4},
#  {'Word': 'Canada',
#   'Phonemes': 'K AE1 N AH0 D AH0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'Finland',
#   'Phonemes': 'F IH1 N L AE2 N D',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'Sweden',
#   'Phonemes': 'S W IY1 D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'United',
#   'Phonemes': 'Y UW0 N AY1 T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'States',
#   'Phonemes': 'S T EY1 T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'The',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'Nations',
#   'Phonemes': 'N EY1 SH AH0 N Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Face',
#   'Phonemes': 'F EY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'off',
#   'Phonemes': 'AO1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'took',
#   'Phonemes': 'T UH1 K',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'place',
#   'Phonemes': 'P L EY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'lieu',
#   'Phonemes': 'L UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'of',
#   'Phonemes': 'AH1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'All',
#   'Phonemes': 'AO1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Star',
#   'Phonemes': 'S T AA1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Game',
#   'Phonemes': 'G EY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Bettman',
#   'Phonemes': 'B EH1 T M AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'stated',
#   'Phonemes': 'S T EY1 T IH0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'that',
#   'Phonemes': 'DH AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'would',
#   'Phonemes': 'W UH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'play',
#   'Phonemes': 'P L EY1',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Winter',
#   'Phonemes': 'W IH1 N T ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Olympics',
#   'Phonemes': 'OW0 L IH1 M P IH0 K S',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'after',
#   'Phonemes': 'AE1 F T ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'they',
#   'Phonemes': 'DH EY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'had',
#   'Phonemes': 'HH AE1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'not',
#   'Phonemes': 'N AA1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'been',
#   'Phonemes': 'B IH1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'released',
#   'Phonemes': 'R IY0 L IY1 S T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'tournaments',
#   'Phonemes': 'T ER1 N AH0 M AH0 N T S',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'Bettman',
#   'Phonemes': 'B EH1 T M AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'also',
#   'Phonemes': 'AO1 L S OW0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'stated',
#   'Phonemes': 'S T EY1 T IH0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'league',
#   'Phonemes': 'L IY1 G',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'would',
#   'Phonemes': 'W UH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'host',
#   'Phonemes': 'HH OW1 S T',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'next',
#   'Phonemes': 'N EH1 K S T',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'World',
#   'Phonemes': 'W ER1 L D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Cups',
#   'Phonemes': 'K AH1 P S',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'of',
#   'Phonemes': 'AH1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Hockey',
#   'Phonemes': 'HH AA1 K IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'most',
#   'Phonemes': 'M OW1 S T',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'recent',
#   'Phonemes': 'R IY1 S AH0 N T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'edition',
#   'Phonemes': 'AH0 D IH1 SH AH0 N',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'held',
#   'Phonemes': 'HH EH1 L D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'At',
#   'Phonemes': 'AE1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'time',
#   'Phonemes': 'T AY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'of',
#   'Phonemes': 'AH1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': "tournament's",
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T S',
#   'Vowel Count': 3,
#   'Consonant Count': 7,
#   'Syllable Count': 3},
#  {'Word': 'announcement',
#   'Phonemes': 'AH0 N AW1 N S M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'all',
#   'Phonemes': 'AO1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'participating',
#   'Phonemes': 'P AA0 R T IH1 S AH0 P EY2 T IH0 NG',
#   'Vowel Count': 5,
#   'Consonant Count': 7,
#   'Syllable Count': 5},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'ranked',
#   'Phonemes': 'R AE1 NG K T',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'top',
#   'Phonemes': 'T AA1 P',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'six',
#   'Phonemes': 'S IH1 K S',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'by',
#   'Phonemes': 'B AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'ice',
#   'Phonemes': 'AY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': "hockey's",
#   'Phonemes': 'HH AA1 K IY0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'worldwide',
#   'Phonemes': 'W ER1 L D W AY1 D',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'governing',
#   'Phonemes': 'G AH1 V ER0 N IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'body',
#   'Phonemes': 'B AA1 D IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'International',
#   'Phonemes': 'IH2 N T ER0 N AE1 SH AH0 N AH0 L',
#   'Vowel Count': 5,
#   'Consonant Count': 6,
#   'Syllable Count': 5},
#  {'Word': 'Ice',
#   'Phonemes': 'AY1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Hockey',
#   'Phonemes': 'HH AA1 K IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'Federation',
#   'Phonemes': 'F EH2 D ER0 EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 4,
#   'Syllable Count': 4},
#  "Word 'IIHF' not found in CMUdict.",
#  {'Word': 'Canada',
#   'Phonemes': 'K AE1 N AH0 D AH0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'Finland',
#   'Phonemes': 'F IH1 N L AE2 N D',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'United',
#   'Phonemes': 'Y UW0 N AY1 T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'States',
#   'Phonemes': 'S T EY1 T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Sweden',
#   'Phonemes': 'S W IY1 D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Germany',
#   'Phonemes': 'JH ER1 M AH0 N IY0',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'while',
#   'Phonemes': 'W AY1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'ranked',
#   'Phonemes': 'R AE1 NG K T',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'fifth',
#   'Phonemes': 'F IH1 F TH',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'did',
#   'Phonemes': 'D IH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'not',
#   'Phonemes': 'N AA1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'have',
#   'Phonemes': 'HH AE1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'enough',
#   'Phonemes': 'IH0 N AH1 F',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'create',
#   'Phonemes': 'K R IY0 EY1 T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'roster',
#   'Phonemes': 'R AA1 S T ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Though',
#   'Phonemes': 'DH OW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'they',
#   'Phonemes': 'DH EY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'had',
#   'Phonemes': 'HH AE1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'enough',
#   'Phonemes': 'IH0 N AH1 F',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  "Word 'NHL' not found in CMUdict.",
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'create',
#   'Phonemes': 'K R IY0 EY1 T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'roster',
#   'Phonemes': 'R AA1 S T ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'Russia',
#   'Phonemes': 'R AH1 SH AH0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'ranked',
#   'Phonemes': 'R AE1 NG K T',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'third',
#   'Phonemes': 'TH ER1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'eighth',
#   'Phonemes': 'EY1 T TH',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'not',
#   'Phonemes': 'N AA1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'included',
#   'Phonemes': 'IH2 N K L UW1 D AH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'with',
#   'Phonemes': 'W IH1 DH',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'Russia',
#   'Phonemes': 'R AH1 SH AH0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'specifically',
#   'Phonemes': 'S P AH0 S IH1 F IH0 K L IY0',
#   'Vowel Count': 4,
#   'Consonant Count': 6,
#   'Syllable Count': 4},
#  {'Word': 'excluded',
#   'Phonemes': 'IH0 K S K L UW1 D AH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'due',
#   'Phonemes': 'D UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'ban',
#   'Phonemes': 'B AE1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'imposed',
#   'Phonemes': 'IH2 M P OW1 Z D',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'on',
#   'Phonemes': 'AA1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'it',
#   'Phonemes': 'IH1 T',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'by',
#   'Phonemes': 'B AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'IIHF' not found in CMUdict.",
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'ongoing',
#   'Phonemes': 'AA1 N G OW2 IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'war',
#   'Phonemes': 'W AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'Ukraine',
#   'Phonemes': 'Y UW0 K R EY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'Czech',
#   'Phonemes': 'CH EH1 K',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'forward',
#   'Phonemes': 'F AO1 R W ER0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'David',
#   'Phonemes': 'D EY1 V IH0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  "Word 'Pastrnak' not found in CMUdict.",
#  {'Word': 'called',
#   'Phonemes': 'K AO1 L D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'omission',
#   'Phonemes': 'OW0 M IH1 SH AH0 N',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'of',
#   'Phonemes': 'AH1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  "Word 'Czechia' not found in CMUdict.",
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'huge',
#   'Phonemes': 'HH Y UW1 JH',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'though',
#   'Phonemes': 'DH OW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'he',
#   'Phonemes': 'HH IY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'said',
#   'Phonemes': 'S EH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'he',
#   'Phonemes': 'HH IY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'understood',
#   'Phonemes': 'AH2 N D ER0 S T UH1 D',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'there',
#   'Phonemes': 'DH EH1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'limited',
#   'Phonemes': 'L IH1 M AH0 T AH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'time',
#   'Phonemes': 'T AY1 M',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'organize',
#   'Phonemes': 'AO1 R G AH0 N AY2 Z',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tournament',
#   'Phonemes': 'T UH1 R N AH0 M AH0 N T',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'In',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'early',
#   'Phonemes': 'ER1 L IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 1,
#   'Syllable Count': 2},
#  {'Word': 'reporting',
#   'Phonemes': 'R IY0 P AO1 R T IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  {'Word': 'on',
#   'Phonemes': 'AA1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
# ...
#   'Syllable Count': 1},
#  {'Word': 'sudden',
#   'Phonemes': 'S AH1 D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'death',
#   'Phonemes': 'D EH1 TH',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'period',
#   'Phonemes': 'P IH1 R IY0 AH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'followed',
#   'Phonemes': 'F AA1 L OW0 D',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'by',
#   'Phonemes': 'B AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'three',
#   'Phonemes': 'TH R IY1',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'round',
#   'Phonemes': 'R AW1 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'shootout',
#   'Phonemes': 'SH UW1 T AW0 T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'In',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'final',
#   'Phonemes': 'F AY1 N AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'overtime',
#   'Phonemes': 'OW1 V ER0 T AY2 M',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'was',
#   'Phonemes': 'W AA1 Z',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'held',
#   'Phonemes': 'HH EH1 L D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'consecutive',
#   'Phonemes': 'K AH0 N S EH1 K Y AH0 T IH0 V',
#   'Vowel Count': 4,
#   'Consonant Count': 7,
#   'Syllable Count': 4},
#  {'Word': 'minute',
#   'Phonemes': 'M IH1 N AH0 T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'on',
#   'Phonemes': 'AA1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'sudden',
#   'Phonemes': 'S AH1 D AH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'death',
#   'Phonemes': 'D EH1 TH',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'periods',
#   'Phonemes': 'P IH1 R IY0 AH0 D Z',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'Teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'ranked',
#   'Phonemes': 'R AE1 NG K T',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'according',
#   'Phonemes': 'AH0 K AO1 R D IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'points',
#   'Phonemes': 'P OY1 N T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'earned',
#   'Phonemes': 'ER1 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'points',
#   'Phonemes': 'P OY1 N T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'regulation',
#   'Phonemes': 'R EH2 G Y AH0 L EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 6,
#   'Syllable Count': 4},
#  {'Word': 'win',
#   'Phonemes': 'W IH1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'points',
#   'Phonemes': 'P OY1 N T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'an',
#   'Phonemes': 'AE1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'overtime',
#   'Phonemes': 'OW1 V ER0 T AY2 M',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'or',
#   'Phonemes': 'AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'shootout',
#   'Phonemes': 'SH UW1 T AW0 T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'win',
#   'Phonemes': 'W IH1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'point',
#   'Phonemes': 'P OY1 N T',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'an',
#   'Phonemes': 'AE1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'overtime',
#   'Phonemes': 'OW1 V ER0 T AY2 M',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'or',
#   'Phonemes': 'AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'shootout',
#   'Phonemes': 'SH UW1 T AW0 T',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'loss',
#   'Phonemes': 'L AO1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'points',
#   'Phonemes': 'P OY1 N T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'a',
#   'Phonemes': 'AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 0,
#   'Syllable Count': 1},
#  {'Word': 'regulation',
#   'Phonemes': 'R EH2 G Y AH0 L EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 6,
#   'Syllable Count': 4},
#  {'Word': 'loss',
#   'Phonemes': 'L AO1 S',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'If',
#   'Phonemes': 'IH1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tied',
#   'Phonemes': 'T AY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'on',
#   'Phonemes': 'AA1 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'points',
#   'Phonemes': 'P OY1 N T S',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  "Word 'tiebreakers' not found in CMUdict.",
#  {'Word': 'would',
#   'Phonemes': 'W UH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'be',
#   'Phonemes': 'B IY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'applied',
#   'Phonemes': 'AH0 P L AY1 D',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'the',
#   'Phonemes': 'DH AH0',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'following',
#   'Phonemes': 'F AA1 L OW0 IH0 NG',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'order',
#   'Phonemes': 'AO1 R D ER0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'Head',
#   'Phonemes': 'HH EH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'to',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'head',
#   'Phonemes': 'HH EH1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'result',
#   'Phonemes': 'R IH0 Z AH1 L T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'only',
#   'Phonemes': 'OW1 N L IY0',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'if',
#   'Phonemes': 'IH1 F',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'tie',
#   'Phonemes': 'T AY1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'two',
#   'Phonemes': 'T UW1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Total',
#   'Phonemes': 'T OW1 T AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'regulation',
#   'Phonemes': 'R EH2 G Y AH0 L EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 6,
#   'Syllable Count': 4},
#  {'Word': 'wins',
#   'Phonemes': 'W IH1 N Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Total',
#   'Phonemes': 'T OW1 T AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'regulation',
#   'Phonemes': 'R EH2 G Y AH0 L EY1 SH AH0 N',
#   'Vowel Count': 4,
#   'Consonant Count': 6,
#   'Syllable Count': 4},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'overtime',
#   'Phonemes': 'OW1 V ER0 T AY2 M',
#   'Vowel Count': 3,
#   'Consonant Count': 3,
#   'Syllable Count': 3},
#  {'Word': 'wins',
#   'Phonemes': 'W IH1 N Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Total',
#   'Phonemes': 'T OW1 T AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'goal',
#   'Phonemes': 'G OW1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'difference',
#   'Phonemes': 'D IH1 F ER0 AH0 N S',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'Total',
#   'Phonemes': 'T OW1 T AH0 L',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'goals',
#   'Phonemes': 'G OW1 L Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'scored',
#   'Phonemes': 'S K AO1 R D',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'Goal',
#   'Phonemes': 'G OW1 L',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'difference',
#   'Phonemes': 'D IH1 F ER0 AH0 N S',
#   'Vowel Count': 3,
#   'Consonant Count': 4,
#   'Syllable Count': 3},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'games',
#   'Phonemes': 'G EY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'played',
#   'Phonemes': 'P L EY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'tied',
#   'Phonemes': 'T AY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Goals',
#   'Phonemes': 'G OW1 L Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'scored',
#   'Phonemes': 'S K AO1 R D',
#   'Vowel Count': 1,
#   'Consonant Count': 4,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'games',
#   'Phonemes': 'G EY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'played',
#   'Phonemes': 'P L EY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'tied',
#   'Phonemes': 'T AY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Most',
#   'Phonemes': 'M OW1 S T',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'even',
#   'Phonemes': 'IY1 V IH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'strength',
#   'Phonemes': 'S T R EH1 NG K TH',
#   'Vowel Count': 1,
#   'Consonant Count': 6,
#   'Syllable Count': 1},
#  {'Word': 'goals',
#   'Phonemes': 'G OW1 L Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'for',
#   'Phonemes': 'F AO1 R',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'games',
#   'Phonemes': 'G EY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'played',
#   'Phonemes': 'P L EY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'tied',
#   'Phonemes': 'T AY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Fewest',
#   'Phonemes': 'F Y UW1 AH0 S T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'even',
#   'Phonemes': 'IY1 V IH0 N',
#   'Vowel Count': 2,
#   'Consonant Count': 2,
#   'Syllable Count': 2},
#  {'Word': 'strength',
#   'Phonemes': 'S T R EH1 NG K TH',
#   'Vowel Count': 1,
#   'Consonant Count': 6,
#   'Syllable Count': 1},
#  {'Word': 'goals',
#   'Phonemes': 'G OW1 L Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'against',
#   'Phonemes': 'AH0 G EH1 N S T',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'in',
#   'Phonemes': 'IH0 N',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'games',
#   'Phonemes': 'G EY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'played',
#   'Phonemes': 'P L EY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'between',
#   'Phonemes': 'B IH0 T W IY1 N',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'tied',
#   'Phonemes': 'T AY1 D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  {'Word': 'teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'Teams',
#   'Phonemes': 'T IY1 M Z',
#   'Vowel Count': 1,
#   'Consonant Count': 3,
#   'Syllable Count': 1},
#  {'Word': 'consisted',
#   'Phonemes': 'K AH0 N S IH1 S T AH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 6,
#   'Syllable Count': 3},
#  {'Word': 'of',
#   'Phonemes': 'AH1 V',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'skaters',
#   'Phonemes': 'S K EY1 T ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 4,
#   'Syllable Count': 2},
#  {'Word': 'forwards',
#   'Phonemes': 'F AO1 R W ER0 D Z',
#   'Vowel Count': 2,
#   'Consonant Count': 5,
#   'Syllable Count': 2},
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  "Word 'defencemen' not found in CMUdict.",
#  {'Word': 'and',
#   'Phonemes': 'AH0 N D',
#   'Vowel Count': 1,
#   'Consonant Count': 2,
#   'Syllable Count': 1},
#  "Word 'goaltenders' not found in CMUdict.",
#  {'Word': 'Players',
#   'Phonemes': 'P L EY1 ER0 Z',
#   'Vowel Count': 2,
#   'Consonant Count': 3,
#   'Syllable Count': 2},
#  {'Word': 'were',
#   'Phonemes': 'W ER1',
#   'Vowel Count': 1,
#   'Consonant Count': 1,
#   'Syllable Count': 1},
#  {'Word': 'selected',
#   'Phonemes': 'S AH0 L EH1 K T IH0 D',
#   'Vowel Count': 3,
#   'Consonant Count': 5,
#   'Syllable Count': 3},
#  ...]

# %%
from enum import Enum
from pydantic import BaseModel

class ARPAbet(Enum):
    # Vowels
    AA = "AA"  # odd
    AE = "AE"  # at
    AH = "AH"  # hut
    AO = "AO"  # ought
    AW = "AW"  # cow
    AY = "AY"  # hide
    EH = "EH"  # end
    ER = "ER"  # hurt
    EY = "EY"  # ate
    IH = "IH"  # it
    IY = "IY"  # eat
    OW = "OW"  # oat
    OY = "OY"  # toy
    UH = "UH"  # book
    UW = "UW"  # two

    # Consonants
    B = "B"  # bat
    CH = "CH"  # chin
    D = "D"  # day
    DH = "DH"  # they
    F = "F"  # fat
    G = "G"  # go
    HH = "HH"  # hat
    JH = "JH"  # judge
    K = "K"  # kite
    L = "L"  # let
    M = "M"  # man
    N = "N"  # nap
    NG = "NG"  # sing
    P = "P"  # pet
    R = "R"  # red
    S = "S"  # sit
    SH = "SH"  # she
    T = "T"  # top
    TH = "TH"  # thin
    V = "V"  # van
    W = "W"  # win
    Y = "Y"  # yes
    Z = "Z"  # zoo
    ZH = "ZH"  # measure

    # special
    START = "START" # the begining of a word
    END = "END" # the end of a word

def phones_for_word(word: str):
    phoneme_list = pronouncing.phones_for_word(word)

    if not phoneme_list or len(phoneme_list) == 0:
        raise ValueError(f"Word '{word}' not found in CMUdict.")
    
    top_variant = phoneme_list[0]
    phonemes = top_variant.split()

    arpa_bet = []
    for phoneme in phonemes:
        if len(phoneme) == 3:
            phoneme = phoneme[:2]
        
        arpa_bet.append(ARPAbet[phoneme])
        
    return arpa_bet

class Edge(BaseModel):
    Left: ARPAbet
    Right: ARPAbet
    Count: int

class Graph():
    connections: list[Edge]

    def __init__(self):
        self.connections = []
    
    def add_word(word: str):
        phoneme_list = pronouncing.phones_for_word(word)
        
    def __add_edge(start: ARPAbet, end: ARPAbet):
        pass

phones_for_word("hello")
# Out:
# [<ARPAbet.HH: 'HH'>, <ARPAbet.AH: 'AH'>, <ARPAbet.L: 'L'>, <ARPAbet.OW: 'OW'>]

# %%
def is_vowel(phoneme):
    return phoneme[-1].isdigit()

def vowel_count(phonemes):
    return len([p for p in phonemes if is_vowel(p)])

def contains_vowel(phonemes):
    return vowel_count(phonemes) >= 1

def get_syllables(word):
    phonemes = pronouncing.phones_for_word(word)
    if phonemes is None or len(phonemes) == 0:
        raise ValueError(f"unknown word {word}")
    
    phonemes = phonemes[0].split()

    print(phonemes)
    # word is only a single sylable
    if vowel_count(phonemes) == 1:
        return [phonemes]

    syllable = []
    syllables = []
    for p in reversed(phonemes):
        if is_vowel(p) and contains_vowel(syllable):
            syllables.insert(0, syllable)
            syllable = []
        
        syllable.insert(0, p)
    
    if len(syllable) > 0:
        syllables.insert(0, syllable)

    return syllables


for title, article in dataset.items():
    print(title)
    words = split_words(article)
    for word in words:
        print("---")
        print(word)
        syllable = get_syllables(word)
        print(syllable)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 37
#      32         syllables.insert(0, syllable)
#      34     return syllables
# ---> 37 for title, article in dataset.items():
#      38     print(title)
#      39     words = split_words(article)
#
# NameError: name 'dataset' is not defined

# %%
from enum import Enum
import pronouncing

class Sonority(Enum):
    # Vowels (highest sonority)
    AA = 6
    AE = 6
    AH = 6
    AO = 6
    AW = 6
    AY = 6
    EH = 6
    ER = 6
    EY = 6
    IH = 6
    IY = 6
    OW = 6
    OY = 6
    UH = 6
    UW = 6

    # Glides (semi-vowels)
    W = 5
    Y = 5

    # Liquids
    L = 4
    R = 4

    # Nasals
    M = 3
    N = 3
    NG = 3

    # Fricatives
    DH = 2
    F = 2
    V = 2
    TH = 2
    S = 2
    Z = 2
    SH = 2
    ZH = 2
    HH = 2

    # Plosives (Stops)
    B = 1
    D = 1
    G = 1
    K = 1
    P = 1
    T = 1
    CH = 1
    JH = 1

def get_sonority(phoneme):
    """
    Returns the sonority score of an ARPAbet phoneme.
    """
    phoneme = phoneme.strip("012")  # Remove stress markers
    return Sonority[phoneme].value if phoneme in Sonority.__members__ else 0  # Default to 0 for unknown phonemes

def syllabify(phonemes):
    """
    Segments a list of phonemes into syllables using the Sonority Sequencing Principle (SSP).
    """
    syllables = []
    current_syllable = []

    for i, phoneme in enumerate(phonemes):
        sonority = get_sonority(phoneme)

        if i > 0:
            prev_sonority = get_sonority(phonemes[i - 1])
            
            # If the current phoneme has lower sonority than the previous, it marks a syllable boundary
            if sonority < prev_sonority:
                syllables.append(current_syllable)
                current_syllable = []

        current_syllable.append(phoneme)

    # Add the last syllable
    if current_syllable:
        syllables.append(current_syllable)

    return ["-".join(syl) for syl in syllables]

def get_word_syllables(word):
    """
    Converts a word into ARPAbet phonemes and applies syllabification.
    """
    phoneme_lists = pronouncing.phones_for_word(word.lower())

    if not phoneme_lists:
        return f"No pronunciation found for '{word}'"

    # Take the first pronunciation (CMU Dictionary can have multiple)
    phonemes = phoneme_lists[0].split()
    return syllabify(phonemes)

# Example Usage
words = ["syllable", "computer", "elephant", "phonetics", "beautiful"]

for word in words:
    print(f"{word}: {get_word_syllables(word)}")
# Out:
# syllable: ['S-IH1', 'L-AH0', 'B-AH0', 'L']
# computer: ['K-AH0', 'M', 'P-Y-UW1', 'T-ER0']
# elephant: ['EH1', 'L-AH0', 'F-AH0', 'N', 'T']
# phonetics: ['F-AH0', 'N-EH1', 'T-IH0', 'K-S']
# beautiful: ['B-Y-UW1', 'T-AH0', 'F-AH0', 'L']

# %%
phonemens = pronouncing.phones_for_word("extra")[0].split()
sonorities = [get_sonority(p) for p in phonemens]

# pre-process sonorities to handle special case for 'S'
for i in range(len(phonemens)):
    p = phonemens[i]
    s = sonorities[i]
    s_before = sonorities[i - 1] if i > 0 else s
    s_after = sonorities[i + 1] if i < len(phonemens) - 1 else s

    # special case for english cause it's weird
    if p == "S":
        print("before", s, s_before, s_after)
    if p == "S" and s_before < s and s > s_after:
        sonorities[i] = -1
        print("after", s, s_before, s_after)


syllable = []
syllables = []
for i in reversed(range(len(phonemens))):
    p = phonemens[i]
    s = sonorities[i]
    s_before = sonorities[i - 1] if i > 0 else s
    s_after = sonorities[i + 1] if i < len(phonemens) - 1 else s

    if is_vowel(p) and contains_vowel(syllable):
        syllables.insert(0, syllable)
        syllable= [p]
        continue


    syllable.insert(0, p)
    if s_before > s and s < s_after:
        syllables.insert(0, syllable)
        syllable= []
    

if len(syllable) > 0:
    syllables.insert(0, syllable)

syllables
# Out:
# before 2 1 1
# after 2 1 1
# [['EH1', 'K'], ['S', 'T', 'R', 'AH0']]

# %%
import pronouncing

def get_syllables(word):
    # check if there's an inner capital like in words McDonald or iPhone
    # this check dosen't catch single letter words but that's fine since
    # those words will just be a single syllable anyway
    if word[1:].lower() != word[1:]:
        chars = [" "+char if char.isupper() else char for char in word]
        words = "".join(chars).split()
        syllables = []
        for word in words:
            # this is important for words like D'Angelo
            word = word.removesuffix("'")
            syllables.extend(get_syllables(word))

        return syllables

    phonemens = pronouncing.phones_for_word(word.lower())
    if phonemens is None or len(phonemens) == 0:
        raise ValueError(f"unknown word '{word}'")

    phonemens= phonemens[0].split()
    sonorities = [get_sonority(p) for p in phonemens]

    # pre-process sonorities to handle special case for 'S'
    for i in range(len(phonemens)):
        p = phonemens[i]
        s = sonorities[i]
        s_before = sonorities[i - 1] if i > 0 else -1
        s_after = sonorities[i + 1] if i < len(phonemens) - 1 else -1

        # special case for english cause it's weird
        if p == "S" and s_before < s and s > s_after:
            sonorities[i] = -1

    syllable = []
    syllables = []
    for i in reversed(range(len(phonemens))):
        p = phonemens[i]
        s = sonorities[i]
        s_before = sonorities[i - 1] if i > 0 else s
        s_after = sonorities[i + 1] if i < len(phonemens) - 1 else s

        if is_vowel(p) and contains_vowel(syllable):
            syllables.insert(0, syllable)
            syllable= [p]
            continue

        syllable.insert(0, p)
        if s_before > s and s < s_after and contains_vowel(syllable):
            syllables.insert(0, syllable)
            syllable= []


    if len(syllable) > 0:
        syllables.insert(0, syllable)

    return syllables

# test cases
cases = [
    # long words
    ("championship", [['CH', 'AE1', 'M'], ['P', 'IY0'], ['AH0', 'N'], ['SH', 'IH2', 'P']]),

    # words with apostraphies
    ("tournament's", [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T', 'S']]),
    ("can't", [['K', 'AE1', 'N', 'T']]),
    ("won't", [['W', 'OW1', 'N', 'T']]),
    ("shouldn't", [['SH', 'UH1'], ['D', 'AH0', 'N', 'T']]),

    # words with inner capital letters
    ("McDonald", [['M', 'IH0', 'K'], ['D', 'AA1'], ['N', 'AH0', 'L', 'D']]),
    ("D'Angelo", [['D', 'IY1'], ['AE1', 'N'], ['JH', 'AH0'], ['L', 'OW2']]),
    ("iPhone", [['AY1'], ['F', 'OW1', 'N']]),
    ("eBay", [['IY1'], ['B', 'EY1']]),
    ("CoPilot", [['K', 'OW1'], ['P', 'AY1'], ['L', 'AH0', 'T']]),

    # words with adjacent vowels
    ("fire", [['F', 'AY1'], ['ER0']]),
    ("hour", [['AW1'], ['ER0']]),
    ("player", [['P', 'L', 'EY1'], ['ER0']]),

    # words with silent letters
    ("knight", [['N', 'AY1', 'T']]),
    ("aisle", [['AY1', 'L']]),
    ("subtle", [['S', 'AH1'], ['T', 'AH0', 'L']]),

    # words with schwa
    ("separate", [['S', 'EH1'], ['P', 'ER0'], ['EY2', 'T']]),
    ("camera", [['K', 'AE1'], ['M', 'ER0'], ['AH0']]),
    ("family", [['F', 'AE1'], ['M', 'AH0'], ['L', 'IY0']]),

    # words with consonant clusters
    ("strength", [['S', 'T', 'R', 'EH1', 'NG', 'K', 'TH']]),
    ("sprints", [['S', 'P', 'R', 'IH1', 'N', 'T', 'S']]),
    ("through", [['TH', 'R', 'UW1']]),
    ("blasts", [['B', 'L', 'AE1', 'S', 'T', 'S']]),

    # compound words
    ("football", [['F', 'UH1', 'T'], ['B', 'AO2', 'L']]),
    ("wallpaper", [['W', 'AO1', 'L'], ['P', 'EY2'], ['P', 'ER0']]),
    ("bookshelf", [['B', 'UH1', 'K'], ['SH', 'EH2', 'L', 'F']]),

    # unusual stress patterns
    ("guitar", [['G', 'IH0'], ['T', 'AA1', 'R']]),
    ("police", [['P', 'AH0'], ['L', 'IY1', 'S']]),

    # loan words
    ("croissant", [['K', 'W', 'AA2'], ['S', 'AA1', 'N', 'T']]),
    ("cliche", [['K', 'L', 'IY0'], ['SH', 'EY1']]),
    ("karaoke", [['K', 'EH2'], ['R', 'IY0'], ['OW1'], ['K', 'IY0']]),

    # exceptions to the sonority sequencing principal
    ("psalm", [['S', 'AA1', 'L', 'M']]),
    ("sphere", [['S', 'F', 'IH1', 'R']]),
    ("split", [['S', 'P', 'L', 'IH1', 'T']]),
    ("sprint", [['S', 'P', 'R', 'IH1', 'N', 'T']]),
    ("sphinx", [['S', 'F', 'IH1', 'NG', 'K', 'S']]),
    ("thrive", [['TH', 'R', 'AY1', 'V']]),
    ("free", [['F', 'R', 'IY1']]),
    ("twelfth", [['T', 'W', 'EH1', 'L', 'F', 'TH']]),
    ("lengths", [['L', 'EH1', 'NG', 'K', 'TH', 'S']]),
    ("strength", [['S', 'T', 'R', 'EH1', 'NG', 'K', 'TH']]),
]
print("running test cases")
fail = False
for case in cases:
    word = case[0]
    want = case[1]
    got = get_syllables(word)
    if got != want:
        print(f"\n{word}: incorrect syllables got {got} but wanted {want}")
        fail = True
    else:
        print(".", end="")

assert not fail, "one or more test cases failed"
# Out:
# running test cases
# .......................
# football: incorrect syllables got [['F', 'UH1'], ['T', 'B', 'AO2', 'L']] but wanted [['F', 'UH1', 'T'], ['B', 'AO2', 'L']]
# .
# bookshelf: incorrect syllables got [['B', 'UH1'], ['K', 'SH', 'EH2', 'L', 'F']] but wanted [['B', 'UH1', 'K'], ['SH', 'EH2', 'L', 'F']]
# ...............
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 137
#     134     else:
#     135         print(".", end="")
# --> 137 assert not fail, "one or more test cases failed"
#
# AssertionError: one or more test cases failed

# %%
for title, article in dataset.items():
    print(title)
    words = split_words(article)
    for word in words:
        print("---")
        print(word)
        try:
            syllable = get_syllables(word)
        except Exception:
            print("[]")
            continue
        print(syllable)
    break
# Out:
# 2025_4_Nations_Face-Off
# ---
# The
# [['DH', 'AH0']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# French
# [['F', 'R', 'EH1', 'N', 'CH']]
# ---
# Confrontation
# [['K', 'AA2', 'N'], ['F', 'R', 'AH0', 'N'], ['T', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# des
# [['D', 'EH1', 'S']]
# ---
# nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# an
# [['AE1', 'N']]
# ---
# international
# [['IH2', 'N'], ['T', 'ER0'], ['N', 'AE1'], ['SH', 'AH0'], ['N', 'AH0', 'L']]
# ---
# ice
# [['AY1', 'S']]
# ---
# hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# held
# [['HH', 'EH1', 'L', 'D']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# The
# [['DH', 'AH0']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# Montreal
# [['M', 'AH2', 'N'], ['T', 'R', 'IY0'], ['AO1', 'L']]
# ---
# at
# [['AE1', 'T']]
# ---
# Bell
# [['B', 'EH1', 'L']]
# ---
# Centre
# [['S', 'EH1', 'N'], ['T', 'ER0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# Boston
# [['B', 'AA1', 'S'], ['T', 'AH0', 'N']]
# ---
# at
# [['AE1', 'T']]
# ---
# TD
# [['T', 'IY1'], ['D', 'IY1']]
# ---
# Garden
# [['G', 'AA1', 'R'], ['D', 'AH0', 'N']]
# ---
# Hosted
# [['HH', 'OW1', 'S'], ['T', 'IH0', 'D']]
# ---
# by
# [['B', 'AY1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# National
# [['N', 'AE1'], ['SH', 'AH0'], ['N', 'AH0', 'L']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# League
# [['L', 'IY1', 'G']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# featuring
# [['F', 'IY1'], ['CH', 'ER0'], ['IH0', 'NG']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# temporarily
# [['T', 'EH2', 'M'], ['P', 'ER0'], ['EH1'], ['R', 'AH0'], ['L', 'IY0']]
# ---
# replaced
# [['R', 'IY2'], ['P', 'L', 'EY1', 'S', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL's
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L', 'Z']]
# ---
# annual
# [['AE1'], ['N', 'Y', 'UW0'], ['AH0', 'L']]
# ---
# All
# [['AO1', 'L']]
# ---
# Star
# [['S', 'T', 'AA1', 'R']]
# ---
# Game
# [['G', 'EY1', 'M']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# In
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# representing
# [['R', 'EH2'], ['P', 'R', 'IH0'], ['Z', 'EH1', 'N'], ['T', 'IH0', 'NG']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# Finland
# [['F', 'IH1'], ['N', 'L', 'AE2', 'N', 'D']]
# ---
# Sweden
# [['S', 'W', 'IY1'], ['D', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# each
# [['IY1', 'CH']]
# ---
# other
# [['AH1'], ['DH', 'ER0']]
# ---
# in
# [['IH0', 'N']]
# ---
# a
# [['AH0']]
# ---
# round
# [['R', 'AW1', 'N', 'D']]
# ---
# robin
# [['R', 'AA1'], ['B', 'AH0', 'N']]
# ---
# format
# [['F', 'AO1', 'R'], ['M', 'AE2', 'T']]
# ---
# followed
# [['F', 'AA1'], ['L', 'OW0', 'D']]
# ---
# by
# [['B', 'AY1']]
# ---
# a
# [['AH0']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# two
# [['T', 'UW1']]
# ---
# top
# [['T', 'AA1', 'P']]
# ---
# placed
# [['P', 'L', 'EY1', 'S', 'T']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Although
# [['AO2', 'L'], ['DH', 'OW1']]
# ---
# each
# [['IY1', 'CH']]
# ---
# team's
# [['T', 'IY1', 'M', 'Z']]
# ---
# respective
# [['R', 'IH0', 'S'], ['P', 'EH1'], ['K', 'T', 'IH0', 'V']]
# ---
# national
# [['N', 'AE1'], ['SH', 'AH0'], ['N', 'AH0', 'L']]
# ---
# ice
# [['AY1', 'S']]
# ---
# hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# governing
# [['G', 'AH1'], ['V', 'ER0'], ['N', 'IH0', 'NG']]
# ---
# body
# [['B', 'AA1'], ['D', 'IY0']]
# ---
# selected
# [['S', 'AH0'], ['L', 'EH1'], ['K', 'T', 'IH0', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# rosters
# [['R', 'AA1', 'S'], ['T', 'ER0', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# an
# [['AE1', 'N']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# event
# [['IH0'], ['V', 'EH1', 'N', 'T']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# affiliated
# [['AH0'], ['F', 'IH1'], ['L', 'IY0'], ['EY2'], ['T', 'IH0', 'D']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# the
# [['DH', 'AH0']]
# ---
# International
# [['IH2', 'N'], ['T', 'ER0'], ['N', 'AE1'], ['SH', 'AH0'], ['N', 'AH0', 'L']]
# ---
# Ice
# [['AY1', 'S']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# Federation
# [['F', 'EH2'], ['D', 'ER0'], ['EY1'], ['SH', 'AH0', 'N']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# won
# [['W', 'AH1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# after
# [['AE1', 'F'], ['T', 'ER0']]
# ---
# defeating
# [['D', 'IH0'], ['F', 'IY1'], ['T', 'IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# overtime
# [['OW1'], ['V', 'ER0'], ['T', 'AY2', 'M']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# Reactions
# [['R', 'IY0'], ['AE1'], ['K', 'SH', 'AH0', 'N', 'Z']]
# ---
# to
# [['T', 'UW1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# sports
# [['S', 'P', 'AO1', 'R', 'T', 'S']]
# ---
# journalists
# [['JH', 'ER1'], ['N', 'AH0'], ['L', 'AH0', 'S', 'T', 'S']]
# ---
# were
# [['W', 'ER1']]
# ---
# positive
# [['P', 'AA1'], ['Z', 'AH0'], ['T', 'IH0', 'V']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# viewed
# [['V', 'Y', 'UW1', 'D']]
# ---
# as
# [['AE1', 'Z']]
# ---
# a
# [['AH0']]
# ---
# welcome
# [['W', 'EH1', 'L'], ['K', 'AH0', 'M']]
# ---
# change
# [['CH', 'EY1', 'N', 'JH']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# the
# [['DH', 'AH0']]
# ---
# All
# [['AO1', 'L']]
# ---
# Star
# [['S', 'T', 'AA1', 'R']]
# ---
# Game
# [['G', 'EY1', 'M']]
# ---
# format
# [['F', 'AO1', 'R'], ['M', 'AE2', 'T']]
# ---
# The
# [['DH', 'AH0']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# at
# [['AE1', 'T']]
# ---
# a
# [['AH0']]
# ---
# press
# [['P', 'R', 'EH1', 'S']]
# ---
# conference
# [['K', 'AA1', 'N'], ['F', 'ER0'], ['AH0', 'N', 'S']]
# ---
# at
# [['AE1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# All
# [['AO1', 'L']]
# ---
# Star
# [['S', 'T', 'AA1', 'R']]
# ---
# Game
# [['G', 'EY1', 'M']]
# ---
# on
# [['AA1', 'N']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# by
# [['B', 'AY1']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# commissioner
# [['K', 'AH0'], ['M', 'IH1'], ['SH', 'AH0'], ['N', 'ER0']]
# ---
# Gary
# [['G', 'EH1'], ['R', 'IY0']]
# ---
# Bettman
# [['B', 'EH1'], ['T', 'M', 'AH0', 'N']]
# ---
# Also
# [['AO1', 'L'], ['S', 'OW0']]
# ---
# present
# [['P', 'R', 'EH1'], ['Z', 'AH0', 'N', 'T']]
# ---
# at
# [['AE1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# press
# [['P', 'R', 'EH1', 'S']]
# ---
# conference
# [['K', 'AA1', 'N'], ['F', 'ER0'], ['AH0', 'N', 'S']]
# ---
# were
# [['W', 'ER1']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# Players'
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# Association
# [['AH0'], ['S', 'OW2'], ['S', 'IY0'], ['EY1'], ['SH', 'AH0', 'N']]
# ---
# NHLPA
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L'], ['P', 'IY1'], ['AH0']]
# ---
# executive
# [['IH0'], ['G', 'Z', 'EH1'], ['K', 'Y', 'AH0'], ['T', 'IH0', 'V']]
# ---
# director
# [['D', 'ER0'], ['EH1'], ['K', 'T', 'ER0']]
# ---
# Marty
# [['M', 'AA1', 'R'], ['T', 'IY0']]
# ---
# Walsh
# [['W', 'AO1', 'L', 'SH']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# four
# [['F', 'AO1', 'R']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# Connor
# [['K', 'AA1'], ['N', 'ER0']]
# ---
# McDavid
# [['M', 'IH0', 'K'], ['D', 'EY1'], ['V', 'IH0', 'D']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# Sebastian
# [['S', 'AH0'], ['B', 'AE1', 'S'], ['CH', 'AH0', 'N']]
# ---
# Aho
# [['AA1'], ['HH', 'OW0']]
# ---
# Finland
# [['F', 'IH1'], ['N', 'L', 'AE2', 'N', 'D']]
# ---
# Elias
# [['AH0'], ['L', 'AY1'], ['AH0', 'S']]
# ---
# Pettersson
# [['P', 'IY1'], ['T', 'ER0'], ['S', 'AH0', 'N']]
# ---
# Sweden
# [['S', 'W', 'IY1'], ['D', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Auston
# [['AO1', 'S'], ['T', 'AH0', 'N']]
# ---
# Matthews
# [['M', 'AE1'], ['TH', 'Y', 'UW0', 'Z']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# At
# [['AE1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# press
# [['P', 'R', 'EH1', 'S']]
# ---
# conference
# [['K', 'AA1', 'N'], ['F', 'ER0'], ['AH0', 'N', 'S']]
# ---
# Bettman
# [['B', 'EH1'], ['T', 'M', 'AH0', 'N']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# plans
# [['P', 'L', 'AE1', 'N', 'Z']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# participation
# [['P', 'AA0', 'R'], ['T', 'IH2'], ['S', 'AH0'], ['P', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# in
# [['IH0', 'N']]
# ---
# international
# [['IH2', 'N'], ['T', 'ER0'], ['N', 'AE1'], ['SH', 'AH0'], ['N', 'AH0', 'L']]
# ---
# best
# [['B', 'EH1', 'S', 'T']]
# ---
# on
# [['AA1', 'N']]
# ---
# best
# [['B', 'EH1', 'S', 'T']]
# ---
# tournaments
# [['T', 'ER1'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# coming
# [['K', 'AH1'], ['M', 'IH0', 'NG']]
# ---
# years
# [['Y', 'IH1', 'R', 'Z']]
# ---
# In
# [['IH0', 'N']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# participated
# [['P', 'AA0', 'R'], ['T', 'IH1'], ['S', 'AH0'], ['P', 'EY2'], ['T', 'IH0', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# a
# [['AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# representing
# [['R', 'EH2'], ['P', 'R', 'IH0'], ['Z', 'EH1', 'N'], ['T', 'IH0', 'NG']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# Finland
# [['F', 'IH1'], ['N', 'L', 'AE2', 'N', 'D']]
# ---
# Sweden
# [['S', 'W', 'IY1'], ['D', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# The
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# off
# [['AO1', 'F']]
# ---
# took
# [['T', 'UH1', 'K']]
# ---
# place
# [['P', 'L', 'EY1', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# lieu
# [['L', 'UW1']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# All
# [['AO1', 'L']]
# ---
# Star
# [['S', 'T', 'AA1', 'R']]
# ---
# Game
# [['G', 'EY1', 'M']]
# ---
# Bettman
# [['B', 'EH1'], ['T', 'M', 'AH0', 'N']]
# ---
# stated
# [['S', 'T', 'EY1'], ['T', 'IH0', 'D']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# play
# [['P', 'L', 'EY1']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Winter
# [['W', 'IH1', 'N'], ['T', 'ER0']]
# ---
# Olympics
# [['OW0'], ['L', 'IH1', 'M'], ['P', 'IH0', 'K', 'S']]
# ---
# after
# [['AE1', 'F'], ['T', 'ER0']]
# ---
# they
# [['DH', 'EY1']]
# ---
# had
# [['HH', 'AE1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# been
# [['B', 'IH1', 'N']]
# ---
# released
# [['R', 'IY0'], ['L', 'IY1', 'S', 'T']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# tournaments
# [['T', 'ER1'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T', 'S']]
# ---
# Bettman
# [['B', 'EH1'], ['T', 'M', 'AH0', 'N']]
# ---
# also
# [['AO1', 'L'], ['S', 'OW0']]
# ---
# stated
# [['S', 'T', 'EY1'], ['T', 'IH0', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# league
# [['L', 'IY1', 'G']]
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# host
# [['HH', 'OW1', 'S', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# next
# [['N', 'EH1', 'K'], ['S', 'T']]
# ---
# World
# [['W', 'ER1', 'L', 'D']]
# ---
# Cups
# [['K', 'AH1', 'P', 'S']]
# ---
# of
# [['AH1', 'V']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# in
# [['IH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# most
# [['M', 'OW1', 'S', 'T']]
# ---
# recent
# [['R', 'IY1'], ['S', 'AH0', 'N', 'T']]
# ---
# edition
# [['AH0'], ['D', 'IH1'], ['SH', 'AH0', 'N']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# held
# [['HH', 'EH1', 'L', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# At
# [['AE1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# time
# [['T', 'AY1', 'M']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament's
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T', 'S']]
# ---
# announcement
# [['AH0'], ['N', 'AW1', 'N'], ['S', 'M', 'AH0', 'N', 'T']]
# ---
# all
# [['AO1', 'L']]
# ---
# participating
# [['P', 'AA0', 'R'], ['T', 'IH1'], ['S', 'AH0'], ['P', 'EY2'], ['T', 'IH0', 'NG']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# ranked
# [['R', 'AE1', 'NG', 'K', 'T']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# top
# [['T', 'AA1', 'P']]
# ---
# six
# [['S', 'IH1', 'K', 'S']]
# ---
# by
# [['B', 'AY1']]
# ---
# ice
# [['AY1', 'S']]
# ---
# hockey's
# [['HH', 'AA1'], ['K', 'IY0', 'Z']]
# ---
# worldwide
# [['W', 'ER1', 'L'], ['D', 'W', 'AY1', 'D']]
# ---
# governing
# [['G', 'AH1'], ['V', 'ER0'], ['N', 'IH0', 'NG']]
# ---
# body
# [['B', 'AA1'], ['D', 'IY0']]
# ---
# the
# [['DH', 'AH0']]
# ---
# International
# [['IH2', 'N'], ['T', 'ER0'], ['N', 'AE1'], ['SH', 'AH0'], ['N', 'AH0', 'L']]
# ---
# Ice
# [['AY1', 'S']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# Federation
# [['F', 'EH2'], ['D', 'ER0'], ['EY1'], ['SH', 'AH0', 'N']]
# ---
# IIHF
# [['AY1'], ['AY1'], ['EY1', 'CH'], ['EH1', 'F']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# Finland
# [['F', 'IH1'], ['N', 'L', 'AE2', 'N', 'D']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Sweden
# [['S', 'W', 'IY1'], ['D', 'AH0', 'N']]
# ---
# Germany
# [['JH', 'ER1'], ['M', 'AH0'], ['N', 'IY0']]
# ---
# while
# [['W', 'AY1', 'L']]
# ---
# ranked
# [['R', 'AE1', 'NG', 'K', 'T']]
# ---
# fifth
# [['F', 'IH1', 'F', 'TH']]
# ---
# did
# [['D', 'IH1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# have
# [['HH', 'AE1', 'V']]
# ---
# enough
# [['IH0'], ['N', 'AH1', 'F']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# to
# [['T', 'UW1']]
# ---
# create
# [['K', 'R', 'IY0'], ['EY1', 'T']]
# ---
# a
# [['AH0']]
# ---
# roster
# [['R', 'AA1', 'S'], ['T', 'ER0']]
# ---
# Though
# [['DH', 'OW1']]
# ---
# they
# [['DH', 'EY1']]
# ---
# had
# [['HH', 'AE1', 'D']]
# ---
# enough
# [['IH0'], ['N', 'AH1', 'F']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# to
# [['T', 'UW1']]
# ---
# create
# [['K', 'R', 'IY0'], ['EY1', 'T']]
# ---
# a
# [['AH0']]
# ---
# roster
# [['R', 'AA1', 'S'], ['T', 'ER0']]
# ---
# Russia
# [['R', 'AH1'], ['SH', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# ranked
# [['R', 'AE1', 'NG', 'K', 'T']]
# ---
# third
# [['TH', 'ER1', 'D']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# eighth
# [['EY1'], ['T', 'TH']]
# ---
# were
# [['W', 'ER1']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# included
# [['IH2', 'N'], ['K', 'L', 'UW1'], ['D', 'AH0', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# Russia
# [['R', 'AH1'], ['SH', 'AH0']]
# ---
# specifically
# [['S', 'P', 'AH0'], ['S', 'IH1'], ['F', 'IH0'], ['K', 'L', 'IY0']]
# ---
# excluded
# [['IH0', 'K'], ['S', 'K', 'L', 'UW1'], ['D', 'AH0', 'D']]
# ---
# due
# [['D', 'UW1']]
# ---
# to
# [['T', 'UW1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# ban
# [['B', 'AE1', 'N']]
# ---
# imposed
# [['IH2', 'M'], ['P', 'OW1', 'Z', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# it
# [['IH1', 'T']]
# ---
# by
# [['B', 'AY1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# IIHF
# [['AY1'], ['AY1'], ['EY1', 'CH'], ['EH1', 'F']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# ongoing
# [['AA1', 'N'], ['G', 'OW2'], ['IH0', 'NG']]
# ---
# war
# [['W', 'AO1', 'R']]
# ---
# in
# [['IH0', 'N']]
# ---
# Ukraine
# [['Y', 'UW0'], ['K', 'R', 'EY1', 'N']]
# ---
# Czech
# [['CH', 'EH1', 'K']]
# ---
# forward
# [['F', 'AO1'], ['R', 'W', 'ER0', 'D']]
# ---
# David
# [['D', 'EY1'], ['V', 'IH0', 'D']]
# ---
# Pastrnak
# []
# ---
# called
# [['K', 'AO1', 'L', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# omission
# [['OW0'], ['M', 'IH1'], ['SH', 'AH0', 'N']]
# ---
# of
# [['AH1', 'V']]
# ---
# Czechia
# []
# ---
# a
# [['AH0']]
# ---
# huge
# [['HH', 'Y', 'UW1', 'JH']]
# ---
# though
# [['DH', 'OW1']]
# ---
# he
# [['HH', 'IY1']]
# ---
# said
# [['S', 'EH1', 'D']]
# ---
# he
# [['HH', 'IY1']]
# ---
# understood
# [['AH2', 'N'], ['D', 'ER0', 'S'], ['T', 'UH1', 'D']]
# ---
# there
# [['DH', 'EH1', 'R']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# limited
# [['L', 'IH1'], ['M', 'AH0'], ['T', 'AH0', 'D']]
# ---
# time
# [['T', 'AY1', 'M']]
# ---
# to
# [['T', 'UW1']]
# ---
# organize
# [['AO1', 'R'], ['G', 'AH0'], ['N', 'AY2', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# In
# [['IH0', 'N']]
# ---
# early
# [['ER1'], ['L', 'IY0']]
# ---
# reporting
# [['R', 'IY0'], ['P', 'AO1', 'R'], ['T', 'IH0', 'NG']]
# ---
# on
# [['AA1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament's
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T', 'S']]
# ---
# format
# [['F', 'AO1', 'R'], ['M', 'AE2', 'T']]
# ---
# journalist
# [['JH', 'ER1'], ['N', 'AH0'], ['L', 'AH0', 'S', 'T']]
# ---
# Greg
# [['G', 'R', 'EH1', 'G']]
# ---
# Wyshynski
# []
# ---
# wrote
# [['R', 'OW1', 'T']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# competition
# [['K', 'AA2', 'M'], ['P', 'AH0'], ['T', 'IH1'], ['SH', 'AH0', 'N']]
# ---
# could
# [['K', 'UH1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# be
# [['B', 'IY1']]
# ---
# considered
# [['K', 'AH0', 'N'], ['S', 'IH1'], ['D', 'ER0', 'D']]
# ---
# best
# [['B', 'EH1', 'S', 'T']]
# ---
# on
# [['AA1', 'N']]
# ---
# best
# [['B', 'EH1', 'S', 'T']]
# ---
# due
# [['D', 'UW1']]
# ---
# to
# [['T', 'UW1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# omission
# [['OW0'], ['M', 'IH1'], ['SH', 'AH0', 'N']]
# ---
# of
# [['AH1', 'V']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# other
# [['AH1'], ['DH', 'ER0']]
# ---
# ice
# [['AY1', 'S']]
# ---
# hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# powers
# [['P', 'AW1'], ['ER0', 'Z']]
# ---
# The
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# took
# [['T', 'UH1', 'K']]
# ---
# place
# [['P', 'L', 'EY1', 'S']]
# ---
# among
# [['AH0'], ['M', 'AH1', 'NG']]
# ---
# heightened
# [['HH', 'AY1'], ['T', 'AH0', 'N', 'D']]
# ---
# political
# [['P', 'AH0'], ['L', 'IH1'], ['T', 'AH0'], ['K', 'AH0', 'L']]
# ---
# tensions
# [['T', 'EH1', 'N'], ['CH', 'AH0', 'N', 'Z']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# due
# [['D', 'UW1']]
# ---
# to
# [['T', 'UW1']]
# ---
# American
# [['AH0'], ['M', 'EH1'], ['R', 'AH0'], ['K', 'AH0', 'N']]
# ---
# president
# [['P', 'R', 'EH1'], ['Z', 'AH0'], ['D', 'EH2', 'N', 'T']]
# ---
# Donald
# [['D', 'AA1'], ['N', 'AH0', 'L', 'D']]
# ---
# Trump's
# [['T', 'R', 'AH1', 'M', 'P', 'S']]
# ---
# call
# [['K', 'AO1', 'L']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# annexing
# [['AH0'], ['N', 'EH1'], ['K', 'S', 'IH0', 'NG']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# plan
# [['P', 'L', 'AE1', 'N']]
# ---
# to
# [['T', 'UW1']]
# ---
# impose
# [['IH2', 'M'], ['P', 'OW1', 'Z']]
# ---
# tariffs
# [['T', 'EH1'], ['R', 'AH0', 'F', 'S']]
# ---
# on
# [['AA1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# country
# [['K', 'AH1', 'N'], ['T', 'R', 'IY0']]
# ---
# Before
# [['B', 'IH0'], ['F', 'AO1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# Trump
# [['T', 'R', 'AH1', 'M', 'P']]
# ---
# posted
# [['P', 'OW1', 'S'], ['T', 'IH0', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# Truth
# [['T', 'R', 'UW1', 'TH']]
# ---
# Social
# [['S', 'OW1'], ['SH', 'AH0', 'L']]
# ---
# stating
# [['S', 'T', 'EY1'], ['T', 'IH0', 'NG']]
# ---
# he
# [['HH', 'IY1']]
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# be
# [['B', 'IY1']]
# ---
# calling
# [['K', 'AO1'], ['L', 'IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# team
# [['T', 'IY1', 'M']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# will
# [['W', 'IH1', 'L']]
# ---
# someday
# [['S', 'AH1', 'M'], ['D', 'EY2']]
# ---
# maybe
# [['M', 'EY1'], ['B', 'IY0']]
# ---
# soon
# [['S', 'UW1', 'N']]
# ---
# become
# [['B', 'IH0'], ['K', 'AH1', 'M']]
# ---
# our
# [['AW1'], ['ER0']]
# ---
# cherished
# [['CH', 'EH1'], ['R', 'IH0', 'SH', 'T']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# very
# [['V', 'EH1'], ['R', 'IY0']]
# ---
# important
# [['IH2', 'M'], ['P', 'AO1', 'R'], ['T', 'AH0', 'N', 'T']]
# ---
# Fifty
# [['F', 'IH1', 'F'], ['T', 'IY0']]
# ---
# First
# [['F', 'ER1', 'S', 'T']]
# ---
# After
# [['AE1', 'F'], ['T', 'ER0']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# beat
# [['B', 'IY1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# Canadian
# [['K', 'AH0'], ['N', 'EY1'], ['D', 'IY0'], ['AH0', 'N']]
# ---
# Prime
# [['P', 'R', 'AY1', 'M']]
# ---
# Minister
# [['M', 'IH1'], ['N', 'AH0', 'S'], ['T', 'ER0']]
# ---
# Justin
# [['JH', 'AH1', 'S'], ['T', 'AH0', 'N']]
# ---
# Trudeau
# [['T', 'R', 'UW0'], ['D', 'OW1']]
# ---
# tweeted
# [['T', 'W', 'IY1'], ['T', 'IH0', 'D']]
# ---
# You
# [['Y', 'UW1']]
# ---
# can't
# [['K', 'AE1', 'N', 'T']]
# ---
# take
# [['T', 'EY1', 'K']]
# ---
# our
# [['AW1'], ['ER0']]
# ---
# country
# [['K', 'AH1', 'N'], ['T', 'R', 'IY0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# you
# [['Y', 'UW1']]
# ---
# can't
# [['K', 'AE1', 'N', 'T']]
# ---
# take
# [['T', 'EY1', 'K']]
# ---
# our
# [['AW1'], ['ER0']]
# ---
# Before
# [['B', 'IH0'], ['F', 'AO1', 'R']]
# ---
# Canada's
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0', 'Z']]
# ---
# round
# [['R', 'AW1', 'N', 'D']]
# ---
# robin
# [['R', 'AA1'], ['B', 'AH0', 'N']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# against
# [['AH0'], ['G', 'EH1', 'N', 'S', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# Montreal
# [['M', 'AH2', 'N'], ['T', 'R', 'IY0'], ['AO1', 'L']]
# ---
# fans
# [['F', 'AE1', 'N', 'Z']]
# ---
# booed
# [['B', 'UW1', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# American
# [['AH0'], ['M', 'EH1'], ['R', 'AH0'], ['K', 'AH0', 'N']]
# ---
# anthem
# [['AE1', 'N'], ['TH', 'AH0', 'M']]
# ---
# which
# [['W', 'IH1', 'CH']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# responded
# [['R', 'IH0', 'S'], ['P', 'AA1', 'N'], ['D', 'IH0', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# by
# [['B', 'AY1']]
# ---
# fans
# [['F', 'AE1', 'N', 'Z']]
# ---
# booing
# [['B', 'UW1'], ['IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Canadian
# [['K', 'AH0'], ['N', 'EY1'], ['D', 'IY0'], ['AH0', 'N']]
# ---
# anthem
# [['AE1', 'N'], ['TH', 'AH0', 'M']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# in
# [['IH0', 'N']]
# ---
# Boston
# [['B', 'AA1', 'S'], ['T', 'AH0', 'N']]
# ---
# Anthem
# [['AE1', 'N'], ['TH', 'AH0', 'M']]
# ---
# singer
# [['S', 'IH1'], ['NG', 'ER0']]
# ---
# Chantal
# [['CH', 'AE1', 'N'], ['T', 'AH0', 'L']]
# ---
# Kreviazuk
# []
# ---
# changed
# [['CH', 'EY1', 'N', 'JH', 'D']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# lines
# [['L', 'AY1', 'N', 'Z']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Canadian
# [['K', 'AH0'], ['N', 'EY1'], ['D', 'IY0'], ['AH0', 'N']]
# ---
# anthem
# [['AE1', 'N'], ['TH', 'AH0', 'M']]
# ---
# to
# [['T', 'UW1']]
# ---
# sing
# [['S', 'IH1', 'NG']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# us
# [['AH1', 'S']]
# ---
# instead
# [['IH2', 'N', 'S'], ['T', 'EH1', 'D']]
# ---
# of
# [['AH1', 'V']]
# ---
# in
# [['IH0', 'N']]
# ---
# all
# [['AO1', 'L']]
# ---
# of
# [['AH1', 'V']]
# ---
# us
# [['AH1', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# response
# [['R', 'IH0', 'S'], ['P', 'AA1', 'N', 'S']]
# ---
# to
# [['T', 'UW1']]
# ---
# Trump's
# [['T', 'R', 'AH1', 'M', 'P', 'S']]
# ---
# annexation
# [['AE2'], ['N', 'EH0'], ['K', 'S', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# rhetoric
# [['R', 'EH1'], ['T', 'ER0'], ['IH0', 'K']]
# ---
# Following
# [['F', 'AA1'], ['L', 'OW0'], ['IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# MVP
# [['EH1', 'M'], ['V', 'IY1'], ['P', 'IY1']]
# ---
# Nathan
# [['N', 'EY1'], ['TH', 'AH0', 'N']]
# ---
# MacKinnon
# []
# ---
# stated
# [['S', 'T', 'EY1'], ['T', 'IH0', 'D']]
# ---
# A
# [['AH0']]
# ---
# lot
# [['L', 'AA1', 'T']]
# ---
# of
# [['AH1', 'V']]
# ---
# stuff
# [['S', 'T', 'AH1', 'F']]
# ---
# going
# [['G', 'OW1'], ['IH0', 'NG']]
# ---
# on
# [['AA1', 'N']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# USA
# [['Y', 'UW1'], ['EH1', 'S'], ['AH0']]
# ---
# right
# [['R', 'AY1', 'T']]
# ---
# now
# [['N', 'AW1']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# us
# [['AH1', 'S']]
# ---
# playing
# [['P', 'L', 'EY1'], ['IH0', 'NG']]
# ---
# against
# [['AH0'], ['G', 'EH1', 'N', 'S', 'T']]
# ---
# each
# [['IY1', 'CH']]
# ---
# other
# [['AH1'], ['DH', 'ER0']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# kind
# [['K', 'AY1', 'N', 'D']]
# ---
# of
# [['AH1', 'V']]
# ---
# a
# [['AH0']]
# ---
# perfect
# [['P', 'ER0'], ['F', 'EH1', 'K', 'T']]
# ---
# storm
# [['S', 'T', 'AO1', 'R', 'M']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# our
# [['AW1'], ['ER0']]
# ---
# sport
# [['S', 'P', 'AO1', 'R', 'T']]
# ---
# It
# [['IH1', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# much
# [['M', 'AH1', 'CH']]
# ---
# more
# [['M', 'AO1', 'R']]
# ---
# popular
# [['P', 'AA1'], ['P', 'Y', 'AH0'], ['L', 'ER0']]
# ---
# than
# [['DH', 'AE1', 'N']]
# ---
# even
# [['IY1'], ['V', 'IH0', 'N']]
# ---
# we
# [['W', 'IY1']]
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# have
# [['HH', 'AE1', 'V']]
# ---
# imagined
# [['IH2'], ['M', 'AE1'], ['JH', 'AH0', 'N', 'D']]
# ---
# It
# [['IH1', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# getting
# [['G', 'EH1'], ['T', 'IH0', 'NG']]
# ---
# so
# [['S', 'OW1']]
# ---
# much
# [['M', 'AH1', 'CH']]
# ---
# attention
# [['AH0'], ['T', 'EH1', 'N'], ['SH', 'AH0', 'N']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# our
# [['AW1'], ['ER0']]
# ---
# whole
# [['HH', 'OW1', 'L']]
# ---
# continent
# [['K', 'AA1', 'N'], ['T', 'AH0'], ['N', 'AH0', 'N', 'T']]
# ---
# Canada's
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0', 'Z']]
# ---
# coach
# [['K', 'OW1', 'CH']]
# ---
# Jon
# [['JH', 'AA1', 'N']]
# ---
# Cooper
# [['K', 'UW1'], ['P', 'ER0']]
# ---
# stated
# [['S', 'T', 'EY1'], ['T', 'IH0', 'D']]
# ---
# nd
# []
# ---
# yeah
# [['Y', 'AE1']]
# ---
# did
# [['D', 'IH1', 'D']]
# ---
# we
# [['W', 'IY1']]
# ---
# need
# [['N', 'IY1', 'D']]
# ---
# a
# [['AH0']]
# ---
# win
# [['W', 'IH1', 'N']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# our
# [['AW1'], ['ER0']]
# ---
# team
# [['T', 'IY1', 'M']]
# ---
# but
# [['B', 'AH1', 'T']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# needed
# [['N', 'IY1'], ['D', 'AH0', 'D']]
# ---
# a
# [['AH0']]
# ---
# win
# [['W', 'IH1', 'N']]
# ---
# The
# [['DH', 'AH0']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# bared
# [['B', 'EH1', 'R', 'D']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# on
# [['AA1', 'N']]
# ---
# their
# [['DH', 'EH1', 'R']]
# ---
# shoulders
# [['SH', 'OW1', 'L'], ['D', 'ER0', 'Z']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# they
# [['DH', 'EY1']]
# ---
# took
# [['T', 'UH1', 'K']]
# ---
# it
# [['IH1', 'T']]
# ---
# seriously
# [['S', 'IH1'], ['R', 'IY0'], ['AH0'], ['S', 'L', 'IY0']]
# ---
# This
# [['DH', 'IH1', 'S']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# different
# [['D', 'IH1'], ['F', 'ER0'], ['AH0', 'N', 'T']]
# ---
# this
# [['DH', 'IH1', 'S']]
# ---
# wasn't
# [['W', 'AA1'], ['Z', 'AH0', 'N', 'T']]
# ---
# a
# [['AH0']]
# ---
# win
# [['W', 'IH1', 'N']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# themselves
# [['DH', 'EH0', 'M'], ['S', 'EH1', 'L', 'V', 'Z']]
# ---
# this
# [['DH', 'IH1', 'S']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# a
# [['AH0']]
# ---
# win
# [['W', 'IH1', 'N']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# plus
# [['P', 'L', 'AH1', 'S']]
# ---
# million
# [['M', 'IH1'], ['L', 'Y', 'AH0', 'N']]
# ---
# people
# [['P', 'IY1'], ['P', 'AH0', 'L']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# guys
# [['G', 'AY1', 'Z']]
# ---
# knew
# [['N', 'UW1']]
# ---
# it
# [['IH1', 'T']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# they
# [['DH', 'EY1']]
# ---
# delivered
# [['D', 'IH0'], ['L', 'IH1'], ['V', 'ER0', 'D']]
# ---
# The
# [['DH', 'AH0']]
# ---
# political
# [['P', 'AH0'], ['L', 'IH1'], ['T', 'AH0'], ['K', 'AH0', 'L']]
# ---
# tension
# [['T', 'EH1', 'N'], ['SH', 'AH0', 'N']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# compared
# [['K', 'AH0', 'M'], ['P', 'EH1', 'R', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Summit
# [['S', 'AH1'], ['M', 'AH0', 'T']]
# ---
# Series
# [['S', 'IH1'], ['R', 'IY0', 'Z']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Soviet
# [['S', 'OW1'], ['V', 'IY0'], ['AH0', 'T']]
# ---
# Union
# [['Y', 'UW1'], ['N', 'Y', 'AH0', 'N']]
# ---
# The
# [['DH', 'AH0']]
# ---
# league
# [['L', 'IY1', 'G']]
# ---
# did
# [['D', 'IH1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# initially
# [['IH2'], ['N', 'IH1'], ['SH', 'AH0'], ['L', 'IY0']]
# ---
# announce
# [['AH0'], ['N', 'AW1', 'N', 'S']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# venues
# [['V', 'EH1'], ['N', 'UW0', 'Z']]
# ---
# but
# [['B', 'AH1', 'T']]
# ---
# stated
# [['S', 'T', 'EY1'], ['T', 'IH0', 'D']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# there
# [['DH', 'EH1', 'R']]
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# be
# [['B', 'IY1']]
# ---
# two
# [['T', 'UW1']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# in
# [['IH0', 'N']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# The
# [['DH', 'AH0']]
# ---
# league
# [['L', 'IY1', 'G']]
# ---
# confirmed
# [['K', 'AH0', 'N'], ['F', 'ER1', 'M', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# June
# [['JH', 'UW1', 'N']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# venues
# [['V', 'EH1'], ['N', 'UW0', 'Z']]
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# be
# [['B', 'IY1']]
# ---
# Bell
# [['B', 'EH1', 'L']]
# ---
# Centre
# [['S', 'EH1', 'N'], ['T', 'ER0']]
# ---
# in
# [['IH0', 'N']]
# ---
# Montreal
# [['M', 'AH2', 'N'], ['T', 'R', 'IY0'], ['AO1', 'L']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# TD
# [['T', 'IY1'], ['D', 'IY1']]
# ---
# Garden
# [['G', 'AA1', 'R'], ['D', 'AH0', 'N']]
# ---
# in
# [['IH0', 'N']]
# ---
# Boston
# [['B', 'AA1', 'S'], ['T', 'AH0', 'N']]
# ---
# after
# [['AE1', 'F'], ['T', 'ER0']]
# ---
# months
# [['M', 'AH1', 'N', 'TH', 'S']]
# ---
# of
# [['AH1', 'V']]
# ---
# reports
# [['R', 'IH0'], ['P', 'AO1', 'R', 'T', 'S']]
# ---
# by
# [['B', 'AY1']]
# ---
# various
# [['V', 'EH1'], ['R', 'IY0'], ['AH0', 'S']]
# ---
# media
# [['M', 'IY1'], ['D', 'IY0'], ['AH0']]
# ---
# sources
# [['S', 'AO1', 'R'], ['S', 'AH0', 'Z']]
# ---
# Two
# [['T', 'UW1']]
# ---
# practice
# [['P', 'R', 'AE1'], ['K', 'T', 'AH0', 'S']]
# ---
# days
# [['D', 'EY1', 'Z']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# were
# [['W', 'ER1']]
# ---
# held
# [['HH', 'EH1', 'L', 'D']]
# ---
# prior
# [['P', 'R', 'AY1'], ['ER0']]
# ---
# to
# [['T', 'UW1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# From
# [['F', 'R', 'AH1', 'M']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# seven
# [['S', 'EH1'], ['V', 'AH0', 'N']]
# ---
# total
# [['T', 'OW1'], ['T', 'AH0', 'L']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# The
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# held
# [['HH', 'EH1', 'L', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# a
# [['AH0']]
# ---
# round
# [['R', 'AW1', 'N', 'D']]
# ---
# robin
# [['R', 'AA1'], ['B', 'AH0', 'N']]
# ---
# format
# [['F', 'AO1', 'R'], ['M', 'AE2', 'T']]
# ---
# Each
# [['IY1', 'CH']]
# ---
# team
# [['T', 'IY1', 'M']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# three
# [['TH', 'R', 'IY1']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# two
# [['T', 'UW1']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# the
# [['DH', 'AH0']]
# ---
# most
# [['M', 'OW1', 'S', 'T']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# advanced
# [['AH0'], ['D', 'V', 'AE1', 'N', 'S', 'T']]
# ---
# to
# [['T', 'UW1']]
# ---
# a
# [['AH0']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# Games
# [['G', 'EY1', 'M', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# sized
# [['S', 'AY1', 'Z', 'D']]
# ---
# rinks
# [['R', 'IH1', 'NG', 'K', 'S']]
# ---
# following
# [['F', 'AA1'], ['L', 'OW0'], ['IH0', 'NG']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# rules
# [['R', 'UW1', 'L', 'Z']]
# ---
# For
# [['F', 'AO1', 'R']]
# ---
# round
# [['R', 'AW1', 'N', 'D']]
# ---
# robin
# [['R', 'AA1'], ['B', 'AH0', 'N']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# overtime
# [['OW1'], ['V', 'ER0'], ['T', 'AY2', 'M']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# a
# [['AH0']]
# ---
# minute
# [['M', 'IH1'], ['N', 'AH0', 'T']]
# ---
# on
# [['AA1', 'N']]
# ---
# sudden
# [['S', 'AH1'], ['D', 'AH0', 'N']]
# ---
# death
# [['D', 'EH1', 'TH']]
# ---
# period
# [['P', 'IH1'], ['R', 'IY0'], ['AH0', 'D']]
# ---
# followed
# [['F', 'AA1'], ['L', 'OW0', 'D']]
# ---
# by
# [['B', 'AY1']]
# ---
# a
# [['AH0']]
# ---
# three
# [['TH', 'R', 'IY1']]
# ---
# round
# [['R', 'AW1', 'N', 'D']]
# ---
# shootout
# [['SH', 'UW1'], ['T', 'AW0', 'T']]
# ---
# In
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# final
# [['F', 'AY1'], ['N', 'AH0', 'L']]
# ---
# overtime
# [['OW1'], ['V', 'ER0'], ['T', 'AY2', 'M']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# held
# [['HH', 'EH1', 'L', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# consecutive
# [['K', 'AH0', 'N'], ['S', 'EH1'], ['K', 'Y', 'AH0'], ['T', 'IH0', 'V']]
# ---
# minute
# [['M', 'IH1'], ['N', 'AH0', 'T']]
# ---
# on
# [['AA1', 'N']]
# ---
# sudden
# [['S', 'AH1'], ['D', 'AH0', 'N']]
# ---
# death
# [['D', 'EH1', 'TH']]
# ---
# periods
# [['P', 'IH1'], ['R', 'IY0'], ['AH0'], ['D', 'Z']]
# ---
# Teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# ranked
# [['R', 'AE1', 'NG', 'K', 'T']]
# ---
# according
# [['AH0'], ['K', 'AO1', 'R'], ['D', 'IH0', 'NG']]
# ---
# to
# [['T', 'UW1']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# earned
# [['ER1', 'N', 'D']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# a
# [['AH0']]
# ---
# regulation
# [['R', 'EH2'], ['G', 'Y', 'AH0'], ['L', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# win
# [['W', 'IH1', 'N']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# an
# [['AE1', 'N']]
# ---
# overtime
# [['OW1'], ['V', 'ER0'], ['T', 'AY2', 'M']]
# ---
# or
# [['AO1', 'R']]
# ---
# shootout
# [['SH', 'UW1'], ['T', 'AW0', 'T']]
# ---
# win
# [['W', 'IH1', 'N']]
# ---
# point
# [['P', 'OY1', 'N', 'T']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# an
# [['AE1', 'N']]
# ---
# overtime
# [['OW1'], ['V', 'ER0'], ['T', 'AY2', 'M']]
# ---
# or
# [['AO1', 'R']]
# ---
# shootout
# [['SH', 'UW1'], ['T', 'AW0', 'T']]
# ---
# loss
# [['L', 'AO1', 'S']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# a
# [['AH0']]
# ---
# regulation
# [['R', 'EH2'], ['G', 'Y', 'AH0'], ['L', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# loss
# [['L', 'AO1', 'S']]
# ---
# If
# [['IH1', 'F']]
# ---
# tied
# [['T', 'AY1', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# tiebreakers
# []
# ---
# would
# [['W', 'UH1', 'D']]
# ---
# be
# [['B', 'IY1']]
# ---
# applied
# [['AH0'], ['P', 'L', 'AY1', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# following
# [['F', 'AA1'], ['L', 'OW0'], ['IH0', 'NG']]
# ---
# order
# [['AO1', 'R'], ['D', 'ER0']]
# ---
# Head
# [['HH', 'EH1', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# head
# [['HH', 'EH1', 'D']]
# ---
# result
# [['R', 'IH0'], ['Z', 'AH1', 'L', 'T']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# if
# [['IH1', 'F']]
# ---
# tie
# [['T', 'AY1']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# two
# [['T', 'UW1']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Total
# [['T', 'OW1'], ['T', 'AH0', 'L']]
# ---
# regulation
# [['R', 'EH2'], ['G', 'Y', 'AH0'], ['L', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# wins
# [['W', 'IH1', 'N', 'Z']]
# ---
# Total
# [['T', 'OW1'], ['T', 'AH0', 'L']]
# ---
# regulation
# [['R', 'EH2'], ['G', 'Y', 'AH0'], ['L', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# overtime
# [['OW1'], ['V', 'ER0'], ['T', 'AY2', 'M']]
# ---
# wins
# [['W', 'IH1', 'N', 'Z']]
# ---
# Total
# [['T', 'OW1'], ['T', 'AH0', 'L']]
# ---
# goal
# [['G', 'OW1', 'L']]
# ---
# difference
# [['D', 'IH1'], ['F', 'ER0'], ['AH0', 'N', 'S']]
# ---
# Total
# [['T', 'OW1'], ['T', 'AH0', 'L']]
# ---
# goals
# [['G', 'OW1', 'L', 'Z']]
# ---
# scored
# [['S', 'K', 'AO1', 'R', 'D']]
# ---
# Goal
# [['G', 'OW1', 'L']]
# ---
# difference
# [['D', 'IH1'], ['F', 'ER0'], ['AH0', 'N', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# tied
# [['T', 'AY1', 'D']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Goals
# [['G', 'OW1', 'L', 'Z']]
# ---
# scored
# [['S', 'K', 'AO1', 'R', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# tied
# [['T', 'AY1', 'D']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Most
# [['M', 'OW1', 'S', 'T']]
# ---
# even
# [['IY1'], ['V', 'IH0', 'N']]
# ---
# strength
# [['S', 'T', 'R', 'EH1', 'NG'], ['K', 'TH']]
# ---
# goals
# [['G', 'OW1', 'L', 'Z']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# in
# [['IH0', 'N']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# tied
# [['T', 'AY1', 'D']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Fewest
# [['F', 'Y', 'UW1'], ['AH0', 'S', 'T']]
# ---
# even
# [['IY1'], ['V', 'IH0', 'N']]
# ---
# strength
# [['S', 'T', 'R', 'EH1', 'NG'], ['K', 'TH']]
# ---
# goals
# [['G', 'OW1', 'L', 'Z']]
# ---
# against
# [['AH0'], ['G', 'EH1', 'N', 'S', 'T']]
# ---
# in
# [['IH0', 'N']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# played
# [['P', 'L', 'EY1', 'D']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# tied
# [['T', 'AY1', 'D']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# consisted
# [['K', 'AH0', 'N'], ['S', 'IH1', 'S'], ['T', 'AH0', 'D']]
# ---
# of
# [['AH1', 'V']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# skaters
# [['S', 'K', 'EY1'], ['T', 'ER0', 'Z']]
# ---
# forwards
# [['F', 'AO1'], ['R', 'W', 'ER0'], ['D', 'Z']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# defencemen
# []
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# goaltenders
# []
# ---
# Players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# selected
# [['S', 'AH0'], ['L', 'EH1'], ['K', 'T', 'IH0', 'D']]
# ---
# by
# [['B', 'AY1']]
# ---
# their
# [['DH', 'EH1', 'R']]
# ---
# respective
# [['R', 'IH0', 'S'], ['P', 'EH1'], ['K', 'T', 'IH0', 'V']]
# ---
# governing
# [['G', 'AH1'], ['V', 'ER0'], ['N', 'IH0', 'NG']]
# ---
# bodies
# [['B', 'AA1'], ['D', 'IY0', 'Z']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Finnish
# [['F', 'IH1'], ['N', 'IH0', 'SH']]
# ---
# Ice
# [['AY1', 'S']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# Association
# [['AH0'], ['S', 'OW2'], ['S', 'IY0'], ['EY1'], ['SH', 'AH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Swedish
# [['S', 'W', 'IY1'], ['D', 'IH0', 'SH']]
# ---
# Ice
# [['AY1', 'S']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# Association
# [['AH0'], ['S', 'OW2'], ['S', 'IY0'], ['EY1'], ['SH', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# USA
# [['Y', 'UW1'], ['EH1', 'S'], ['AH0']]
# ---
# Hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# The
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# restricted
# [['R', 'IY0', 'S'], ['T', 'R', 'IH1'], ['K', 'T', 'AH0', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# who
# [['HH', 'UW1']]
# ---
# have
# [['HH', 'AE1', 'V']]
# ---
# a
# [['AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# contract
# [['K', 'AA1', 'N'], ['T', 'R', 'AE2', 'K', 'T']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# were
# [['W', 'ER1']]
# ---
# on
# [['AA1', 'N']]
# ---
# an
# [['AE1', 'N']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# roster
# [['R', 'AA1', 'S'], ['T', 'ER0']]
# ---
# as
# [['AE1', 'Z']]
# ---
# of
# [['AH1', 'V']]
# ---
# December
# [['D', 'IH0'], ['S', 'EH1', 'M'], ['B', 'ER0']]
# ---
# Because
# [['B', 'IH0'], ['K', 'AO1', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# did
# [['D', 'IH1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# have
# [['HH', 'AE1', 'V']]
# ---
# an
# [['AE1', 'N']]
# ---
# agreement
# [['AH0'], ['G', 'R', 'IY1'], ['M', 'AH0', 'N', 'T']]
# ---
# directly
# [['D', 'ER0'], ['EH1'], ['K', 'T', 'L', 'IY0']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# the
# [['DH', 'AH0']]
# ---
# IIHF
# [['AY1'], ['AY1'], ['EY1', 'CH'], ['EH1', 'F']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# an
# [['AE1', 'N']]
# ---
# agreement
# [['AH0'], ['G', 'R', 'IY1'], ['M', 'AH0', 'N', 'T']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# the
# [['DH', 'AH0']]
# ---
# governing
# [['G', 'AH1'], ['V', 'ER0'], ['N', 'IH0', 'NG']]
# ---
# bodies
# [['B', 'AA1'], ['D', 'IY0', 'Z']]
# ---
# as
# [['AE1', 'Z']]
# ---
# mentioned
# [['M', 'EH1', 'N'], ['SH', 'AH0', 'N', 'D']]
# ---
# above
# [['AH0'], ['B', 'AH1', 'V']]
# ---
# which
# [['W', 'IH1', 'CH']]
# ---
# are
# [['AA1', 'R']]
# ---
# IIHF
# [['AY1'], ['AY1'], ['EY1', 'CH'], ['EH1', 'F']]
# ---
# members
# [['M', 'EH1', 'M'], ['B', 'ER0', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# could
# [['K', 'UH1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# include
# [['IH2', 'N'], ['K', 'L', 'UW1', 'D']]
# ---
# non
# [['N', 'AA1', 'N']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# On
# [['AA1', 'N']]
# ---
# June
# [['JH', 'UW1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# first
# [['F', 'ER1', 'S', 'T']]
# ---
# six
# [['S', 'IH1', 'K', 'S']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# on
# [['AA1', 'N']]
# ---
# each
# [['IY1', 'CH']]
# ---
# team's
# [['T', 'IY1', 'M', 'Z']]
# ---
# roster
# [['R', 'AA1', 'S'], ['T', 'ER0']]
# ---
# The
# [['DH', 'AH0']]
# ---
# remaining
# [['R', 'IH0'], ['M', 'EY1'], ['N', 'IH0', 'NG']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# on
# [['AA1', 'N']]
# ---
# December
# [['D', 'IH0'], ['S', 'EH1', 'M'], ['B', 'ER0']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# the
# [['DH', 'AH0']]
# ---
# complete
# [['K', 'AH0', 'M'], ['P', 'L', 'IY1', 'T']]
# ---
# rosters
# [['R', 'AA1', 'S'], ['T', 'ER0', 'Z']]
# ---
# of
# [['AH1', 'V']]
# ---
# Team
# [['T', 'IY1', 'M']]
# ---
# Sweden
# [['S', 'W', 'IY1'], ['D', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Team
# [['T', 'IY1', 'M']]
# ---
# Finland
# [['F', 'IH1'], ['N', 'L', 'AE2', 'N', 'D']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# at
# [['AE1', 'T']]
# ---
# p
# [['P', 'IY1']]
# ---
# m
# [['EH1', 'M']]
# ---
# ET
# [['IY1'], ['T', 'IY1']]
# ---
# on
# [['AA1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# Network
# [['N', 'EH1'], ['T', 'W', 'ER2', 'K']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# ESPN's
# [['IY1'], ['EH1', 'S'], ['P', 'IY1'], ['EH1', 'N', 'Z']]
# ---
# SportsCenter
# [['S', 'P', 'AO1', 'R', 'T', 'S'], ['S', 'EH1', 'N'], ['T', 'ER0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# complete
# [['K', 'AH0', 'M'], ['P', 'L', 'IY1', 'T']]
# ---
# rosters
# [['R', 'AA1', 'S'], ['T', 'ER0', 'Z']]
# ---
# of
# [['AH1', 'V']]
# ---
# Team
# [['T', 'IY1', 'M']]
# ---
# USA
# [['Y', 'UW1'], ['EH1', 'S'], ['AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Team
# [['T', 'IY1', 'M']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# at
# [['AE1', 'T']]
# ---
# p
# [['P', 'IY1']]
# ---
# m
# [['EH1', 'M']]
# ---
# during
# [['D', 'UH1'], ['R', 'IH0', 'NG']]
# ---
# pregame
# []
# ---
# broadcasts
# [['B', 'R', 'AO1'], ['D', 'K', 'AE2', 'S', 'T', 'S']]
# ---
# on
# [['AA1', 'N']]
# ---
# Sportsnet
# []
# ---
# TNT
# [['T', 'IY1'], ['EH1', 'N'], ['T', 'IY1']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# TVA
# [['T', 'IY1'], ['V', 'IY1'], ['AH0']]
# ---
# Sports
# [['S', 'P', 'AO1', 'R', 'T', 'S']]
# ---
# Initially
# [['IH2'], ['N', 'IH1'], ['SH', 'AH0'], ['L', 'IY0']]
# ---
# no
# [['N', 'OW1']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Seattle
# [['S', 'IY0'], ['AE1'], ['T', 'AH0', 'L']]
# ---
# Kraken
# []
# ---
# or
# [['AO1', 'R']]
# ---
# Washington
# [['W', 'AA1'], ['SH', 'IH0', 'NG'], ['T', 'AH0', 'N']]
# ---
# Capitals
# [['K', 'AE1'], ['P', 'AH0'], ['T', 'AH0', 'L', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# selected
# [['S', 'AH0'], ['L', 'EH1'], ['K', 'T', 'IH0', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# participate
# [['P', 'AA0', 'R'], ['T', 'IH1'], ['S', 'AH0'], ['P', 'EY2', 'T']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# however
# [['HH', 'AW2'], ['EH1'], ['V', 'ER0']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Kraken
# []
# ---
# gained
# [['G', 'EY1', 'N', 'D']]
# ---
# a
# [['AH0']]
# ---
# representative
# [['R', 'EH2'], ['P', 'R', 'AH0'], ['Z', 'EH1', 'N'], ['T', 'AH0'], ['T', 'IH0', 'V']]
# ---
# when
# [['W', 'EH1', 'N']]
# ---
# they
# [['DH', 'EY1']]
# ---
# acquired
# [['AH0'], ['K', 'W', 'AY1'], ['ER0', 'D']]
# ---
# Finland's
# [['F', 'IH1'], ['N', 'L', 'AH0', 'N'], ['D', 'Z']]
# ---
# Kaapo
# []
# ---
# Kakko
# []
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# the
# [['DH', 'AH0']]
# ---
# New
# [['N', 'UW1']]
# ---
# York
# [['Y', 'AO1', 'R', 'K']]
# ---
# Rangers
# [['R', 'EY1', 'N'], ['JH', 'ER0', 'Z']]
# ---
# on
# [['AA1', 'N']]
# ---
# December
# [['D', 'IH0'], ['S', 'EH1', 'M'], ['B', 'ER0']]
# ---
# About
# [['AH0'], ['B', 'AW1', 'T']]
# ---
# a
# [['AH0']]
# ---
# week
# [['W', 'IY1', 'K']]
# ---
# before
# [['B', 'IH0'], ['F', 'AO1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# the
# [['DH', 'AH0']]
# ---
# San
# [['S', 'AE1', 'N']]
# ---
# Jose
# [['HH', 'OW2'], ['Z', 'EY1']]
# ---
# Sharks
# [['SH', 'AA1', 'R', 'K', 'S']]
# ---
# also
# [['AO1', 'L'], ['S', 'OW0']]
# ---
# lost
# [['L', 'AO1', 'S', 'T']]
# ---
# their
# [['DH', 'EH1', 'R']]
# ---
# representation
# [['R', 'EH2'], ['P', 'R', 'AH0'], ['Z', 'EH0', 'N'], ['T', 'EY1'], ['SH', 'AH0', 'N']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# event
# [['IH0'], ['V', 'EH1', 'N', 'T']]
# ---
# by
# [['B', 'AY1']]
# ---
# trading
# [['T', 'R', 'EY1'], ['D', 'IH0', 'NG']]
# ---
# Finland's
# [['F', 'IH1'], ['N', 'L', 'AH0', 'N'], ['D', 'Z']]
# ---
# Mikael
# [['M', 'AH0'], ['K', 'EY1', 'L']]
# ---
# Granlund
# [['G', 'R', 'AE1'], ['N', 'L', 'AH0', 'N', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Dallas
# [['D', 'AE1'], ['L', 'AH0', 'S']]
# ---
# Stars
# [['S', 'T', 'AA1', 'R', 'Z']]
# ---
# making
# [['M', 'EY1'], ['K', 'IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Capitals
# [['K', 'AE1'], ['P', 'AH0'], ['T', 'AH0', 'L', 'Z']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Sharks
# [['SH', 'AA1', 'R', 'K', 'S']]
# ---
# the
# [['DH', 'AH0']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# two
# [['T', 'UW1']]
# ---
# teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# to
# [['T', 'UW1']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# appear
# [['AH0'], ['P', 'IH1', 'R']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# In
# [['IH0', 'N']]
# ---
# April
# [['EY1'], ['P', 'R', 'AH0', 'L']]
# ---
# it
# [['IH1', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# announced
# [['AH0'], ['N', 'AW1', 'N', 'S', 'T']]
# ---
# that
# [['DH', 'AE1', 'T']]
# ---
# Don
# [['D', 'AA1', 'N']]
# ---
# Sweeney
# [['S', 'W', 'IY1'], ['N', 'IY0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Jim
# [['JH', 'IH1', 'M']]
# ---
# Nill
# [['N', 'IH1', 'L']]
# ---
# were
# [['W', 'ER1']]
# ---
# appointed
# [['AH0'], ['P', 'OY1', 'N'], ['T', 'IH0', 'D']]
# ---
# by
# [['B', 'AY1']]
# ---
# Doug
# [['D', 'AH1', 'G']]
# ---
# Armstrong
# [['AA1', 'R', 'M', 'S'], ['T', 'R', 'AA2', 'NG']]
# ---
# as
# [['AE1', 'Z']]
# ---
# Canada's
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0', 'Z']]
# ---
# general
# [['JH', 'EH1'], ['N', 'ER0'], ['AH0', 'L']]
# ---
# manager
# [['M', 'AE1'], ['N', 'AH0'], ['JH', 'ER0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# associate
# [['AH0'], ['S', 'OW1'], ['S', 'IY0'], ['AH0', 'T']]
# ---
# general
# [['JH', 'EH1'], ['N', 'ER0'], ['AH0', 'L']]
# ---
# manager
# [['M', 'AE1'], ['N', 'AH0'], ['JH', 'ER0']]
# ---
# respectively
# [['R', 'IH0', 'S'], ['P', 'EH1'], ['K', 'T', 'IH0'], ['V', 'L', 'IY0']]
# ---
# Both
# [['B', 'OW1', 'TH']]
# ---
# were
# ...
# ---
# John
# [['JH', 'AA1', 'N']]
# ---
# Hynes
# [['HH', 'AY1', 'N', 'Z']]
# ---
# John
# [['JH', 'AA1', 'N']]
# ---
# Tortorella
# [['T', 'AO0', 'R'], ['T', 'AO0'], ['R', 'EH1'], ['L', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# David
# [['D', 'EY1'], ['V', 'IH0', 'D']]
# ---
# Quinn
# [['K', 'W', 'IH1', 'N']]
# ---
# are
# [['AA1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# assistant
# [['AH0'], ['S', 'IH1', 'S'], ['T', 'AH0', 'N', 'T']]
# ---
# coaches
# [['K', 'OW1'], ['CH', 'IH0', 'Z']]
# ---
# On
# [['AA1', 'N']]
# ---
# December
# [['D', 'IH0'], ['S', 'EH1', 'M'], ['B', 'ER0']]
# ---
# the
# [['DH', 'AH0']]
# ---
# entire
# [['IH0', 'N'], ['T', 'AY1'], ['ER0']]
# ---
# roster
# [['R', 'AA1', 'S'], ['T', 'ER0']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# released
# [['R', 'IY0'], ['L', 'IY1', 'S', 'T']]
# ---
# On
# [['AA1', 'N']]
# ---
# January
# [['JH', 'AE1'], ['N', 'Y', 'UW0'], ['EH2'], ['R', 'IY0']]
# ---
# Auston
# [['AO1', 'S'], ['T', 'AH0', 'N']]
# ---
# Matthews
# [['M', 'AE1'], ['TH', 'Y', 'UW0', 'Z']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# named
# [['N', 'EY1', 'M', 'D']]
# ---
# captain
# [['K', 'AE1'], ['P', 'T', 'AH0', 'N']]
# ---
# for
# [['F', 'AO1', 'R']]
# ---
# Team
# [['T', 'IY1', 'M']]
# ---
# USA
# [['Y', 'UW1'], ['EH1', 'S'], ['AH0']]
# ---
# Charlie
# [['CH', 'AA1'], ['R', 'L', 'IY0']]
# ---
# McAvoy
# []
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Matthew
# [['M', 'AE1'], ['TH', 'Y', 'UW0']]
# ---
# Tkachuk
# []
# ---
# were
# [['W', 'ER1']]
# ---
# chosen
# [['CH', 'OW1'], ['Z', 'AH0', 'N']]
# ---
# as
# [['AE1', 'Z']]
# ---
# its
# [['IH1', 'T', 'S']]
# ---
# alternate
# [['AO1', 'L'], ['T', 'ER0'], ['N', 'AH0', 'T']]
# ---
# captains
# [['K', 'AE1'], ['P', 'T', 'AH0', 'N', 'Z']]
# ---
# On
# [['AA1', 'N']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# defenseman
# []
# ---
# Quinn
# [['K', 'W', 'IH1', 'N']]
# ---
# Hughes
# [['HH', 'Y', 'UW1', 'Z']]
# ---
# withdrew
# [['W', 'IH0', 'TH'], ['D', 'R', 'UW1']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# due
# [['D', 'UW1']]
# ---
# to
# [['T', 'UW1']]
# ---
# a
# [['AH0']]
# ---
# lower
# [['L', 'OW1'], ['ER0']]
# ---
# body
# [['B', 'AA1'], ['D', 'IY0']]
# ---
# injury
# [['IH1', 'N'], ['JH', 'ER0'], ['IY0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# replaced
# [['R', 'IY2'], ['P', 'L', 'EY1', 'S', 'T']]
# ---
# by
# [['B', 'AY1']]
# ---
# Jake
# [['JH', 'EY1', 'K']]
# ---
# Sanderson
# [['S', 'AE1', 'N'], ['D', 'ER0'], ['S', 'AH0', 'N']]
# ---
# On
# [['AA1', 'N']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# Quinn
# [['K', 'W', 'IH1', 'N']]
# ---
# Hughes
# [['HH', 'Y', 'UW1', 'Z']]
# ---
# attempted
# [['AH0'], ['T', 'EH1'], ['M', 'P', 'T', 'IH0', 'D']]
# ---
# to
# [['T', 'UW1']]
# ---
# rejoin
# [['R', 'IY0'], ['JH', 'OY1', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# while
# [['W', 'AY1', 'L']]
# ---
# Charlie
# [['CH', 'AA1'], ['R', 'L', 'IY0']]
# ---
# McAvoy
# []
# ---
# withdrew
# [['W', 'IH0', 'TH'], ['D', 'R', 'UW1']]
# ---
# from
# [['F', 'R', 'AH1', 'M']]
# ---
# the
# [['DH', 'AH0']]
# ---
# championship
# [['CH', 'AE1', 'M'], ['P', 'IY0'], ['AH0', 'N'], ['SH', 'IH2', 'P']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# after
# [['AE1', 'F'], ['T', 'ER0']]
# ---
# suffering
# [['S', 'AH1'], ['F', 'ER0'], ['IH0', 'NG']]
# ---
# an
# [['AE1', 'N']]
# ---
# upper
# [['AH1'], ['P', 'ER0']]
# ---
# body
# [['B', 'AA1'], ['D', 'IY0']]
# ---
# injury
# [['IH1', 'N'], ['JH', 'ER0'], ['IY0']]
# ---
# during
# [['D', 'UH1'], ['R', 'IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# against
# [['AH0'], ['G', 'EH1', 'N', 'S', 'T']]
# ---
# Finland
# [['F', 'IH1'], ['N', 'L', 'AE2', 'N', 'D']]
# ---
# but
# [['B', 'AH1', 'T']]
# ---
# ultimately
# [['AH1', 'L'], ['T', 'AH0'], ['M', 'AH0'], ['T', 'L', 'IY0']]
# ---
# did
# [['D', 'IH1', 'D']]
# ---
# not
# [['N', 'AA1', 'T']]
# ---
# rejoin
# [['R', 'IY0'], ['JH', 'OY1', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Team
# [['T', 'IY1', 'M']]
# ---
# USA
# [['Y', 'UW1'], ['EH1', 'S'], ['AH0']]
# ---
# added
# [['AE1'], ['D', 'AH0', 'D']]
# ---
# Tage
# []
# ---
# Thompson
# [['T', 'AA1', 'M'], ['P', 'S', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Brett
# [['B', 'R', 'EH1', 'T']]
# ---
# Pesce
# [['P', 'EH1', 'S']]
# ---
# as
# [['AE1', 'Z']]
# ---
# emergency
# [['IH0'], ['M', 'ER1'], ['JH', 'AH0', 'N'], ['S', 'IY0']]
# ---
# backups
# [['B', 'AE1'], ['K', 'AH2', 'P', 'S']]
# ---
# Jack
# [['JH', 'AE1', 'K']]
# ---
# Eichel
# [['AY1'], ['K', 'AH0', 'L']]
# ---
# Brock
# [['B', 'R', 'AA1', 'K']]
# ---
# Nelson
# [['N', 'EH1', 'L'], ['S', 'AH0', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Brady
# [['B', 'R', 'EY1'], ['D', 'IY0']]
# ---
# Tkachuk
# []
# ---
# served
# [['S', 'ER1', 'V', 'D']]
# ---
# as
# [['AE1', 'Z']]
# ---
# alternate
# [['AO1', 'L'], ['T', 'ER0'], ['N', 'AH0', 'T']]
# ---
# captains
# [['K', 'AE1'], ['P', 'T', 'AH0', 'N', 'Z']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# absence
# [['AE1'], ['B', 'S', 'AH0', 'N', 'S']]
# ---
# of
# [['AH1', 'V']]
# ---
# Matthews
# [['M', 'AE1'], ['TH', 'Y', 'UW0', 'Z']]
# ---
# McAvoy
# []
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Matthew
# [['M', 'AE1'], ['TH', 'Y', 'UW0']]
# ---
# Tkachuk
# []
# ---
# Head
# [['HH', 'EH1', 'D']]
# ---
# coach
# [['K', 'OW1', 'CH']]
# ---
# Mike
# [['M', 'AY1', 'K']]
# ---
# The
# [['DH', 'AH0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# selected
# [['S', 'AH0'], ['L', 'EH1'], ['K', 'T', 'IH0', 'D']]
# ---
# four
# [['F', 'AO1', 'R']]
# ---
# of
# [['AH1', 'V']]
# ---
# their
# [['DH', 'EH1', 'R']]
# ---
# referees
# [['R', 'EH2'], ['F', 'ER0'], ['IY1', 'Z']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# four
# [['F', 'AO1', 'R']]
# ---
# linesmen
# []
# ---
# to
# [['T', 'UW1']]
# ---
# officiate
# [['AH0'], ['F', 'IH1'], ['SH', 'IY0'], ['EY2', 'T']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# Standby
# [['S', 'T', 'AE1'], ['N', 'D', 'B', 'AY1']]
# ---
# referee
# [['R', 'EH2'], ['F', 'ER0'], ['IY1']]
# ---
# Pierre
# [['P', 'IY0'], ['EH1', 'R']]
# ---
# Lambert
# [['L', 'AE1', 'M'], ['B', 'ER0', 'T']]
# ---
# officiated
# [['AH0'], ['F', 'IH1'], ['SH', 'IY0'], ['EY2'], ['T', 'AH0', 'D']]
# ---
# two
# [['T', 'UW1']]
# ---
# periods
# [['P', 'IH1'], ['R', 'IY0'], ['AH0'], ['D', 'Z']]
# ---
# after
# [['AE1', 'F'], ['T', 'ER0']]
# ---
# replacing
# [['R', 'IH0'], ['P', 'L', 'EY1'], ['S', 'IH0', 'NG']]
# ---
# Wes
# [['W', 'EH1', 'S']]
# ---
# McCauley
# [['M', 'IH0', 'K'], ['K', 'AO1'], ['L', 'IY0']]
# ---
# during
# [['D', 'UH1'], ['R', 'IH0', 'NG']]
# ---
# the
# [['DH', 'AH0']]
# ---
# first
# [['F', 'ER1', 'S', 'T']]
# ---
# intermission
# [['IH2', 'N'], ['T', 'ER0'], ['M', 'IH1'], ['SH', 'AH0', 'N']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# Note
# [['N', 'OW1', 'T']]
# ---
# All
# [['AO1', 'L']]
# ---
# times
# [['T', 'AY1', 'M', 'Z']]
# ---
# listed
# [['L', 'IH1', 'S'], ['T', 'AH0', 'D']]
# ---
# are
# [['AA1', 'R']]
# ---
# in
# [['IH0', 'N']]
# ---
# EST
# [['IY1'], ['EH1', 'S'], ['T', 'IY1']]
# ---
# Round
# [['R', 'AW1', 'N', 'D']]
# ---
# Scoring
# [['S', 'K', 'AO1'], ['R', 'IH0', 'NG']]
# ---
# The
# [['DH', 'AH0']]
# ---
# following
# [['F', 'AA1'], ['L', 'OW0'], ['IH0', 'NG']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# led
# [['L', 'EH1', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# in
# [['IH0', 'N']]
# ---
# points
# [['P', 'OY1', 'N', 'T', 'S']]
# ---
# Leading
# [['L', 'IY1'], ['D', 'IH0', 'NG']]
# ---
# The
# [['DH', 'AH0']]
# ---
# following
# [['F', 'AA1'], ['L', 'OW0'], ['IH0', 'NG']]
# ---
# goaltenders
# []
# ---
# led
# [['L', 'EH1', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# in
# [['IH0', 'N']]
# ---
# save
# [['S', 'EY1', 'V']]
# ---
# percentage
# [['P', 'ER0'], ['S', 'EH1', 'N'], ['T', 'AH0', 'JH']]
# ---
# minimum
# [['M', 'IH1'], ['N', 'AH0'], ['M', 'AH0', 'M']]
# ---
# of
# [['AH1', 'V']]
# ---
# team's
# [['T', 'IY1', 'M', 'Z']]
# ---
# total
# [['T', 'OW1'], ['T', 'AH0', 'L']]
# ---
# ice
# [['AY1', 'S']]
# ---
# time
# [['T', 'AY1', 'M']]
# ---
# The
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# broadcast
# [['B', 'R', 'AO1'], ['D', 'K', 'AE2', 'S', 'T']]
# ---
# largely
# [['L', 'AA1', 'R'], ['JH', 'L', 'IY0']]
# ---
# by
# [['B', 'AY1']]
# ---
# the
# [['DH', 'AH0']]
# ---
# NHL's
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L', 'Z']]
# ---
# rightsholders
# []
# ---
# in
# [['IH0', 'N']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# televised
# [['T', 'EH1'], ['L', 'AH0'], ['V', 'AY2', 'Z', 'D']]
# ---
# exclusively
# [['IH0', 'K'], ['S', 'K', 'L', 'UW1'], ['S', 'IH0'], ['V', 'L', 'IY0']]
# ---
# by
# [['B', 'AY1']]
# ---
# Sportsnet
# []
# ---
# in
# [['IH0', 'N']]
# ---
# English
# [['IH1', 'NG'], ['G', 'L', 'IH0', 'SH']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# TVA
# [['T', 'IY1'], ['V', 'IY1'], ['AH0']]
# ---
# Sports
# [['S', 'P', 'AO1', 'R', 'T', 'S']]
# ---
# in
# [['IH0', 'N']]
# ---
# French
# [['F', 'R', 'EH1', 'N', 'CH']]
# ---
# In
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# the
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# divided
# [['D', 'IH0'], ['V', 'AY1'], ['D', 'IH0', 'D']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# ESPN
# [['IY1'], ['EH1', 'S'], ['P', 'IY1'], ['EH1', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# TNT
# [['T', 'IY1'], ['EH1', 'N'], ['T', 'IY1']]
# ---
# Sports
# [['S', 'P', 'AO1', 'R', 'T', 'S']]
# ---
# simulcast
# [['S', 'AY1'], ['M', 'Y', 'AH0', 'L'], ['K', 'AE2', 'S', 'T']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# TNT
# [['T', 'IY1'], ['EH1', 'N'], ['T', 'IY1']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# TruTV
# []
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# streaming
# [['S', 'T', 'R', 'IY1'], ['M', 'IH0', 'NG']]
# ---
# on
# [['AA1', 'N']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# Max
# [['M', 'AE1', 'K', 'S']]
# ---
# with
# [['W', 'IH1', 'DH']]
# ---
# Bleacher
# [['B', 'L', 'IY1'], ['CH', 'ER0']]
# ---
# Report
# [['R', 'IY0'], ['P', 'AO1', 'R', 'T']]
# ---
# sports
# [['S', 'P', 'AO1', 'R', 'T', 'S']]
# ---
# add
# [['AE1', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# One
# [['W', 'AH1', 'N']]
# ---
# round
# [['R', 'AW1', 'N', 'D']]
# ---
# robin
# [['R', 'AA1'], ['B', 'AH0', 'N']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# between
# [['B', 'IH0'], ['T', 'W', 'IY1', 'N']]
# ---
# Canada
# [['K', 'AE1'], ['N', 'AH0'], ['D', 'AH0']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# as
# [['AE1', 'Z']]
# ---
# well
# [['W', 'EH1', 'L']]
# ---
# as
# [['AE1', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# championship
# [['CH', 'AE1', 'M'], ['P', 'IY0'], ['AH0', 'N'], ['SH', 'IH2', 'P']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# were
# [['W', 'ER1']]
# ---
# also
# [['AO1', 'L'], ['S', 'OW0']]
# ---
# streamed
# [['S', 'T', 'R', 'IY1', 'M', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# while
# [['W', 'AY1', 'L']]
# ---
# three
# [['TH', 'R', 'IY1']]
# ---
# games
# [['G', 'EY1', 'M', 'Z']]
# ---
# were
# [['W', 'ER1']]
# ---
# carried
# [['K', 'AE1'], ['R', 'IY0', 'D']]
# ---
# by
# [['B', 'AY1']]
# ---
# ESPN
# [['IY1'], ['EH1', 'S'], ['P', 'IY1'], ['EH1', 'N']]
# ---
# Deportes
# []
# ---
# in
# [['IH0', 'N']]
# ---
# Spanish
# [['S', 'P', 'AE1'], ['N', 'IH0', 'SH']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# one
# [['W', 'AH1', 'N']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# carried
# [['K', 'AE1'], ['R', 'IY0', 'D']]
# ---
# on
# [['AA1', 'N']]
# ---
# broadcast
# [['B', 'R', 'AO1'], ['D', 'K', 'AE2', 'S', 'T']]
# ---
# television
# [['T', 'EH1'], ['L', 'AH0'], ['V', 'IH2'], ['ZH', 'AH0', 'N']]
# ---
# by
# [['B', 'AY1']]
# ---
# ABC
# [['AH0'], ['B', 'IY1'], ['S', 'IY1']]
# ---
# The
# [['DH', 'AH0']]
# ---
# tournament
# [['T', 'UH1', 'R'], ['N', 'AH0'], ['M', 'AH0', 'N', 'T']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# highly
# [['HH', 'AY1'], ['L', 'IY0']]
# ---
# viewed
# [['V', 'Y', 'UW1', 'D']]
# ---
# in
# [['IH0', 'N']]
# ---
# North
# [['N', 'AO1', 'R', 'TH']]
# ---
# America
# [['AH0'], ['M', 'EH1'], ['R', 'AH0'], ['K', 'AH0']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# United
# [['Y', 'UW0'], ['N', 'AY1'], ['T', 'IH0', 'D']]
# ---
# States
# [['S', 'T', 'EY1', 'T', 'S']]
# ---
# the
# [['DH', 'AH0']]
# ---
# championship
# [['CH', 'AE1', 'M'], ['P', 'IY0'], ['AH0', 'N'], ['SH', 'IH2', 'P']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# seen
# [['S', 'IY1', 'N']]
# ---
# by
# [['B', 'AY1']]
# ---
# an
# [['AE1', 'N']]
# ---
# average
# [['AE1'], ['V', 'ER0'], ['IH0', 'JH']]
# ---
# of
# [['AH1', 'V']]
# ---
# million
# [['M', 'IH1'], ['L', 'Y', 'AH0', 'N']]
# ---
# viewers
# [['V', 'Y', 'UW1'], ['ER0', 'Z']]
# ---
# overtaking
# [['OW1'], ['V', 'ER0'], ['T', 'EY2'], ['K', 'IH0', 'NG']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# seven
# [['S', 'EH1'], ['V', 'AH0', 'N']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Stanley
# [['S', 'T', 'AE1'], ['N', 'L', 'IY0']]
# ---
# Cup
# [['K', 'AH1', 'P']]
# ---
# Finals
# [['F', 'AY1'], ['N', 'AH0', 'L', 'Z']]
# ---
# as
# [['AE1', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# fourth
# [['F', 'AO1', 'R', 'TH']]
# ---
# highest
# [['HH', 'AY1'], ['AH0', 'S', 'T']]
# ---
# rated
# [['R', 'EY1'], ['T', 'IH0', 'D']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# telecast
# [['T', 'EH1'], ['L', 'AH0'], ['K', 'AE2', 'S', 'T']]
# ---
# of
# [['AH1', 'V']]
# ---
# all
# [['AO1', 'L']]
# ---
# time
# [['T', 'AY1', 'M']]
# ---
# behind
# [['B', 'IH0'], ['HH', 'AY1', 'N', 'D']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# six
# [['S', 'IH1', 'K', 'S']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Stanley
# [['S', 'T', 'AE1'], ['N', 'L', 'IY0']]
# ---
# Cup
# [['K', 'AH1', 'P']]
# ---
# Finals
# [['F', 'AY1'], ['N', 'AH0', 'L', 'Z']]
# ---
# Sportsnet
# []
# ---
# reported
# [['R', 'IY2'], ['P', 'AO1', 'R'], ['T', 'IH0', 'D']]
# ---
# an
# [['AE1', 'N']]
# ---
# average
# [['AE1'], ['V', 'ER0'], ['IH0', 'JH']]
# ---
# of
# [['AH1', 'V']]
# ---
# million
# [['M', 'IH1'], ['L', 'Y', 'AH0', 'N']]
# ---
# viewers
# [['V', 'Y', 'UW1'], ['ER0', 'Z']]
# ---
# in
# [['IH0', 'N']]
# ---
# the
# [['DH', 'AH0']]
# ---
# championship
# [['CH', 'AE1', 'M'], ['P', 'IY0'], ['AH0', 'N'], ['SH', 'IH2', 'P']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# ranking
# [['R', 'AE1', 'NG'], ['K', 'IH0', 'NG']]
# ---
# behind
# [['B', 'IH0'], ['HH', 'AY1', 'N', 'D']]
# ---
# only
# [['OW1'], ['N', 'L', 'IY0']]
# ---
# game
# [['G', 'EY1', 'M']]
# ---
# seven
# [['S', 'EH1'], ['V', 'AH0', 'N']]
# ---
# of
# [['AH1', 'V']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Stanley
# [['S', 'T', 'AE1'], ['N', 'L', 'IY0']]
# ---
# Cup
# [['K', 'AH1', 'P']]
# ---
# Finals
# [['F', 'AY1'], ['N', 'AH0', 'L', 'Z']]
# ---
# as
# [['AE1', 'Z']]
# ---
# the
# [['DH', 'AH0']]
# ---
# second
# [['S', 'EH1'], ['K', 'AH0', 'N', 'D']]
# ---
# highest
# [['HH', 'AY1'], ['AH0', 'S', 'T']]
# ---
# rated
# [['R', 'EY1'], ['T', 'IH0', 'D']]
# ---
# hockey
# [['HH', 'AA1'], ['K', 'IY0']]
# ---
# telecast
# [['T', 'EH1'], ['L', 'AH0'], ['K', 'AE2', 'S', 'T']]
# ---
# in
# [['IH0', 'N']]
# ---
# network
# [['N', 'EH1'], ['T', 'W', 'ER2', 'K']]
# ---
# history
# [['HH', 'IH1', 'S'], ['T', 'ER0'], ['IY0']]
# ---
# Further
# [['F', 'ER1'], ['DH', 'ER0']]
# ---
# McBride
# [['M', 'IH0', 'K'], ['B', 'R', 'AY1', 'D']]
# ---
# Jim
# [['JH', 'IH1', 'M']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# NHL
# [['EH1', 'N'], ['EY1', 'CH'], ['EH1', 'L']]
# ---
# players
# [['P', 'L', 'EY1'], ['ER0', 'Z']]
# ---
# felt
# [['F', 'EH1', 'L', 'T']]
# ---
# strongly
# [['S', 'T', 'R', 'AO1'], ['NG', 'L', 'IY0']]
# ---
# about
# [['AH0'], ['B', 'AW1', 'T']]
# ---
# representing
# [['R', 'EH2'], ['P', 'R', 'IH0'], ['Z', 'EH1', 'N'], ['T', 'IH0', 'NG']]
# ---
# their
# [['DH', 'EH1', 'R']]
# ---
# countries
# [['K', 'AH1', 'N'], ['T', 'R', 'IY0', 'Z']]
# ---
# The
# [['DH', 'AH0']]
# ---
# league
# [['L', 'IY1', 'G']]
# ---
# listened
# [['L', 'IH1'], ['S', 'AH0', 'N', 'D']]
# ---
# and
# [['AH0', 'N', 'D']]
# ---
# the
# [['DH', 'AH0']]
# ---
# Nations
# [['N', 'EY1'], ['SH', 'AH0', 'N', 'Z']]
# ---
# Face
# [['F', 'EY1', 'S']]
# ---
# Off
# [['AO1', 'F']]
# ---
# was
# [['W', 'AA1', 'Z']]
# ---
# The
# [['DH', 'AH0']]
# ---
# Boston
# [['B', 'AA1', 'S'], ['T', 'AH0', 'N']]
# ---
# Globe
# [['G', 'L', 'OW1', 'B']]
# ---
# Retrieved
# [['R', 'IY0'], ['T', 'R', 'IY1', 'V', 'D']]
# ---
# February
# [['F', 'EH1'], ['B', 'Y', 'AH0'], ['W', 'EH2'], ['R', 'IY0']]
# ---
# External
# [['IH0', 'K'], ['S', 'T', 'ER1'], ['N', 'AH0', 'L']]
# ---
# Official
# [['AH0'], ['F', 'IH1'], ['SH', 'AH0', 'L']]
# ---
# Teams
# [['T', 'IY1', 'M', 'Z']]
# ---
# Rosters
# [['R', 'AA1', 'S'], ['T', 'ER0', 'Z']]
# ---
# Archived
# [['AA1', 'R'], ['K', 'AY2', 'V', 'D']]
