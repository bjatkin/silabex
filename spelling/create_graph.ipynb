# %%
import phoneme as ph

graph = ph.Graph()
graph.add_connections([ph.Phoneme.from_string("S"), ph.Phoneme.from_string("T"), ph.Phoneme.from_string("AH0"), ph.Phoneme.from_string("P")])
graph
# Out:
# Graph(connections=[Connection(left=S, right=T, count=1), Connection(left=T, right=AH, count=1), Connection(left=AH, right=P, count=1)])
