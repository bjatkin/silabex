# %%
import wikipediaapi
import polars as pl
import time

from tqdm import tqdm

wiki_wiki = wikipediaapi.Wikipedia(user_agent='Silabex (opensourceatkinson@gmail.com)', language='en')

def get_featured_articles(limit=1000, seconds_between_request=0.5):
    """
    Fetch featured Wikipedia articles
    """

    featured_page = wiki_wiki.page("Wikipedia:Featured_articles")
    pages = []
    iter = featured_page.links.items()
    tqdm_iter = tqdm(iter, desc="getting wiki pages", total=limit)

    for i, (title, page) in enumerate(tqdm_iter):
        if i >= limit:
            break

        content = {
            "title": title,
            "content": page.text,
            "categories": list(page.categories.keys()),
            "links_to": list(page.links.keys()),
        }

        pages.append(content)
        time.sleep(seconds_between_request)

    return pl.DataFrame(pages)

wiki_articles_df = get_featured_articles()
wiki_articles_df.write_ndjson("data/wikipedia_articles.jsonl")
# Out:
# getting wiki pages: 100%|██████████| 1000/1000 [13:43<00:00,  1.21it/s]
